# %% [markdown]
# Network analysis of a dependency call graph can provide valuable insights into the structure and complexity of your codebase, guiding various refactoring decisions to improve maintainability, readability, and performance. Here are some decisions one could make based on different metrics and analyses:
#
# 1. **Reduce Complexity by Breaking Down Highly Connected Nodes**: Nodes with high out-degree centrality (i.e., modules or functions that depend on many others) might indicate complex components that could be simplified or broken down into smaller, more manageable pieces.
#
# 2. **Identify and Eliminate Circular Dependencies**: Cycles in the dependency graph indicate circular dependencies, which can complicate the architecture and make the system harder to understand and maintain. Refactoring to eliminate these cycles can simplify the dependency structure.
#
# 3. **Reorganize Code to Improve Modularity**: Analysis of strongly and weakly connected components can help identify parts of the code that are too tightly coupled or too loosely connected. You might decide to refactor code to improve modularity, making it easier to understand, test, and maintain.
#
# 4. **Optimize Critical Paths**: Path analysis, including finding the longest paths (which might indicate the deepest dependency chains), can help identify critical paths in your application. Refactoring to shorten these paths can improve performance and reduce the impact of changes.
#
# 5. **Decouple High Betweenness Centrality Nodes**: Nodes with high betweenness centrality act as bridges between different parts of the graph. These might be modules or functions that couple different parts of your system together. Refactoring to reduce their betweenness can help decouple your system's components, improving modularity and potentially reducing the risk of changes in one area rippling through to others.
#
# 6. **Consolidate or Remove Redundant Dependencies**: The dependency graph can reveal redundant dependencies or isolated nodes (modules or functions that are not depended upon or do not depend on others). You might decide to consolidate similar functionalities or remove unused or unnecessary dependencies to simplify the codebase.
#
# 7. **Improve Load Balancing and Scalability**: For distributed systems or microservices architectures, network analysis can help identify bottlenecks or single points of failure. Refactoring for better load distribution or adding redundancy can improve system resilience and scalability.
#
# 8. **Enhance Testability**: By identifying tightly coupled components or complex dependency chains, you can refactor to improve testability. This might involve introducing interfaces or abstraction layers, making it easier to mock dependencies in tests.
#
# 9. **Prioritize Refactoring Efforts**: By combining various metrics, such as centrality measures and the number of cycles, you can prioritize refactoring efforts to focus on the most impactful changes first. This is particularly useful in large codebases where comprehensive refactoring is not feasible in a single effort.
#
# 10. **Architectural Decision Making**: Beyond immediate refactoring, the insights gained from the dependency graph can inform broader architectural decisions, such as adopting microservices, modular monoliths, or other architectural patterns that best fit the observed dependencies and their complexities.
#
# By leveraging network analysis of a dependency call graph, one can make informed decisions that lead to a more maintainable, scalable, and understandable codebase.

# %%
import re
import json
import networkx as nx

# Define a function to extract the node attributes from the node string
def extract_node_attributes(node_string):
    """Extract the name, file, and line attributes from the node string."""
    pattern = r'name=([^\n]+)\nfile=([^\n]+)\nline=(\d+)'
    match = re.search(pattern, node_string)
    if match:
        # Return the matched name, file path, and line number as a tuple
        return match.group(1), match.group(2), match.group(3)
    return None, None, None  # Return None for each attribute if not found

# Define a function that checks whether there is any character in uppercase in the string
def has_uppercase(string):
    """Check if a string has any uppercase character."""
    return any(char.isupper() for char in string)

# Then, define a function to check if a string is in camel case
def is_camel_case(string):
    """Check if a string is in camel case."""
    return bool(re.match(r'^[a-z]+(?:[A-Z][a-z]*)+$', string))

# Suggest snake case names for the nodes with camel case names
def suggest_snake_case_name(camel_case_name):
    """Suggest a snake case name from a camel case name, handling leading underscores, acronyms, and numbers."""
    # Preserve leading underscores
    leading_underscores = ''.join(re.match(r'^_+', camel_case_name)[0] if re.match(r'^_+', camel_case_name) else '')
    # Remove leading underscores for processing
    camel_case_name = re.sub(r'^_+', '', camel_case_name)
    
    # Insert underscores before uppercase letters followed by lowercase letters or preceded by lowercase letters or numbers
    snake_case_name = re.sub(r'(?<=[a-z0-9])([A-Z])|(?<=[A-Z])([A-Z][a-z])', r'_\1\2', camel_case_name)
    
    return leading_underscores + snake_case_name.lower()

# Define a function to suggest a new name for a node based on its attributes
def analyze_dependency_graph(graph): # FIXME: Use the isolate examples below to improve the function
    # Reduce Complexity by Breaking Down Highly Connected Nodes
    out_degree_centrality = nx.out_degree_centrality(graph)
    complex_nodes = {node: centrality for node, centrality in out_degree_centrality.items() if centrality > 0.5}  # Threshold can be adjusted

    # Identify and Eliminate Circular Dependencies
    circular_dependencies = list(nx.simple_cycles(graph))

    # Reorganize Code to Improve Modularity
    strongly_connected_components = [list(c) for c in nx.strongly_connected_components(graph)]
    weakly_connected_components = [list(c) for c in nx.weakly_connected_components(graph)]

    # Optimize Critical Paths
    longest_paths = {}
    for node in nx.topological_sort(graph):
        paths = nx.single_source_shortest_path_length(graph, node)
        longest_paths[node] = max(paths.values()) if paths else 0
    critical_path_length = max(longest_paths.values())
    critical_paths = [node for node, length in longest_paths.items() if length == critical_path_length]

    # Decouple High Betweenness Centrality Nodes
    betweenness_centrality = nx.betweenness_centrality(graph)
    high_betweenness_nodes = {node: centrality for node, centrality in betweenness_centrality.items() if centrality > 0.05}  # Threshold can be adjusted

    # Consolidate or Remove Redundant Dependencies
    redundant_dependencies = [node for node in graph.nodes() if graph.in_degree(node) == 0 and graph.out_degree(node) == 0]

    # Improve Load Balancing and Scalability
    # This analysis might require additional data about the system's architecture and deployment.

    # Enhance Testability
    # Identifying tightly coupled components for refactoring to improve testability might require analyzing the structure and dependencies further.

    # Prioritize Refactoring Efforts
    # Combining various metrics to prioritize refactoring efforts. This step might involve a weighted analysis of the above findings.

    # Architectural Decision Making
    # Insights from the above analyses can inform broader architectural decisions.

    result = {
        "complex_nodes": complex_nodes,
        "circular_dependencies": circular_dependencies,
        "strongly_connected_components": strongly_connected_components,
        "weakly_connected_components": weakly_connected_components,
        "critical_paths": critical_paths,
        "high_betweenness_nodes": high_betweenness_nodes,
        "redundant_dependencies": redundant_dependencies,
        # Placeholder for load balancing and scalability analysis
        # Placeholder for enhancing testability
        # Placeholder for prioritizing refactoring efforts
        # Placeholder for architectural decision making
    }

    return json.dumps(result, indent=2)

# %%
# Step 1: Load the JSON File
with open('./example/dependency_graph.json', 'r') as f:
    graph_data = json.load(f)

# Step 2: Parse Nodes and Edges
nodes = graph_data['nodes']
edges = [(edge['source'], edge['target']) for edge in graph_data['edges']]

# Step 3: Analyze the Graph
# Initialize a graph object
G = nx.DiGraph()
G.add_nodes_from(nodes)
G.add_edges_from(edges)

# Basic Analysis
num_nodes = G.number_of_nodes()
num_edges = G.number_of_edges()
print(f"Number of nodes: {num_nodes}")
print(f"Number of edges: {num_edges}")
# Out:
# Number of nodes: 590
# Number of edges: 1031

# %%
# Advanced Analysis

# Print the node with the highest in-degree
in_degree_centrality = nx.in_degree_centrality(G)
node_max_in_degree = max(in_degree_centrality, key=in_degree_centrality.get)
print(f"Node with highest in-degree:\n{node_max_in_degree}")
# Out:
# Node with highest in-degree:
# name=fetchItemValue
# file=wwpdb/apps/deposit/depui/apilayer.py
# line=8833

# %%
# Print the node with the highest out-degree
out_degree_centrality = nx.out_degree_centrality(G)
node_max_out_degree = max(out_degree_centrality, key=out_degree_centrality.get)
print(f"Node with highest out-degree:\n{node_max_out_degree}")
# Out:
# Node with highest out-degree:
# name=updateViewContext
# file=wwpdb/apps/deposit/depui/views.py
# line=369

# %%
# Identify nodes having only one outgoing edge
nodes_with_one_outgoing_edge = [node for node in G.nodes if G.out_degree(node) == 1]
print(f"Nodes with only one outgoing edge: {json.dumps(nodes_with_one_outgoing_edge, indent=2)}")
# Out:
# Nodes with only one outgoing edge: [
#   "name=selectRows\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=255",
#   "name=exist\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=593",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=42",
#   "name=__init__\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=13",
#   "name=__init__\nfile=wwpdb/io/locator/DataReference.py\nline=243",
#   "name=__init__\nfile=wwpdb/utils/wf/DataValueContainer.py\nline=34",
#   "name=__init__\nfile=wwpdb/utils/wf/DataSelector.py\nline=35",
#   "name=setStorageType\nfile=wwpdb/io/locator/DataReference.py\nline=464",
#   "name=setWorkflowInstanceId\nfile=wwpdb/io/locator/DataReference.py\nline=543",
#   "name=setDepositionDataSetId\nfile=wwpdb/io/locator/DataReference.py\nline=521",
#   "name=setContentTypeAndFormat\nfile=wwpdb/io/locator/DataReference.py\nline=414",
#   "name=__isInternalReferenceValid\nfile=wwpdb/io/locator/DataReference.py\nline=784",
#   "name=__getInternalFileNameBase\nfile=wwpdb/io/locator/DataReference.py\nline=915",
#   "name=__latestVersion\nfile=wwpdb/io/locator/DataReference.py\nline=1105",
#   "name=getPartitionNumberSearchTarget\nfile=wwpdb/io/locator/DataReference.py\nline=1181",
#   "name=check_em_valid\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2800",
#   "name=check_complexErrors\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2360",
#   "name=addStatus\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1324",
#   "name=validate_getUploadValidate\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6089",
#   "name=reset_ligands_and_status\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2593",
#   "name=remove_old_maps\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10393",
#   "name=getDBstatus\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=60",
#   "name=noValidate\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6788",
#   "name=get_em_map_upload\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2916",
#   "name=saveListToPickle\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6672",
#   "name=ss_create_long_event\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1330",
#   "name=check_block_edit\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2556",
#   "name=copy_from_tempdep_to_deposit\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2610",
#   "name=runSelectSQL\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=195",
#   "name=close\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=22",
#   "name=runInsertNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=141",
#   "name=runInsertSQL\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=190",
#   "name=runInsertSQL\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=151",
#   "name=runInsert\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=151",
#   "name=close\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=141",
#   "name=createLongEvent\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=604",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/snapshot/Experiments.py\nline=40",
#   "name=getCodes\nfile=wwpdb/apps/deposit/depui/snapshot/Experiments.py\nline=67",
#   "name=runSelectNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=26",
#   "name=getRequestedCodes\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3498",
#   "name=getDataType\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3510",
#   "name=getExperiments\nfile=wwpdb/apps/deposit/depui/snapshot/Experiments.py\nline=45",
#   "name=getDirPathReference\nfile=wwpdb/io/locator/DataReference.py\nline=719",
#   "name=getDir\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=135",
#   "name=getUploadsFile\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=141",
#   "name=path\nfile=wwpdb/apps/deposit/depui/models.py\nline=199",
#   "name=getExperimentsWithSubtypes\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3537",
#   "name=get_all_flags\nfile=wwpdb/apps/deposit/depui/snapshot/EntryFlags.py\nline=28",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/snapshot/EntryFlags.py\nline=23",
#   "name=process_new_files\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=138",
#   "name=get_submitted_warning\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=194",
#   "name=check_diffraction\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=423",
#   "name=check_nmr\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=276",
#   "name=check_ec\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=498",
#   "name=create_onedep_folder\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1498",
#   "name=does_pickle_exist\nfile=wwpdb/apps/deposit/depui/PickleUtil.py\nline=85",
#   "name=load_from_pickle\nfile=wwpdb/apps/deposit/depui/PickleUtil.py\nline=248",
#   "name=clean_em_categories\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9432",
#   "name=is_em_or_ec\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10191",
#   "name=update_em_map_file_names\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10199",
#   "name=check_em_map_matches_DB\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10226",
#   "name=isNmrUnifiedDeposition\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9908",
#   "name=isNmrLegacyDeposition\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9885",
#   "name=get_em_map_upload_index\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10441",
#   "name=validateInstance\nfile=wwpdb/apps/deposit/depui/validation.py\nline=22",
#   "name=createFileEvent\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=598",
#   "name=calculate_centre_of_mass_for_xray\nfile=wwpdb/apps/deposit/depui/upload.py\nline=334",
#   "name=do_file_merge\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1667",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/hiddenData/setHidden.py\nline=34",
#   "name=setPartitionNumber\nfile=wwpdb/io/locator/DataReference.py\nline=603",
#   "name=shutil_copy\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=147",
#   "name=checkNonAscii\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=943",
#   "name=complexLogFile\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=1263",
#   "name=wfStart\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=100",
#   "name=wfFinished\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=74",
#   "name=wfStatus\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=104",
#   "name=runUpdateSQL\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=172",
#   "name=getWfStatus\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=132",
#   "name=createActionEvent\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=610",
#   "name=convertFileEvent\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=592",
#   "name=dumpReport\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=716",
#   "name=getProcessPartition\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=516",
#   "name=getReportData\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=733",
#   "name=get_file_for_content_type_format\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=97",
#   "name=getLatestMapReportFile\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=700",
#   "name=fetch_converted_file\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=576",
#   "name=get_coordinate_errors\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=258",
#   "name=get_structure_factor_report_json_contents\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=48",
#   "name=populate_sf_report\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=71",
#   "name=get_method_specific_errors\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=193",
#   "name=get_coords_issues_json_contents\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=32",
#   "name=populate_coordinate_cell_issues\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=77",
#   "name=get_sequence_issues\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=124",
#   "name=updateCIF\nfile=wwpdb/apps/deposit/depui/precalc/createIDs.py\nline=165",
#   "name=getPickleBaseDictionary\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/dictionary_access.py\nline=35",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=41",
#   "name=__getDataBlock\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=401",
#   "name=__setCategoryByName\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=353",
#   "name=__getInstanceItemIndex\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=440",
#   "name=add_uploaded_files\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=812",
#   "name=write_out_issues_json\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=744",
#   "name=prepare_issues_for_json\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=724",
#   "name=addData\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=835",
#   "name=stripContent\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=790",
#   "name=get_polymer_sequences\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=309",
#   "name=getNewInstance\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=255",
#   "name=get_next_pdbx_for_content_type\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=206",
#   "name=update_recursive\nfile=wwpdb/apps/deposit/depui/upload.py\nline=3363",
#   "name=getBlockList\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=113",
#   "name=getPickleDictionary\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/dictionary_access.py\nline=27",
#   "name=get\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/PdbxDictionaryLoader.py\nline=40",
#   "name=enumerateListHacks\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7502",
#   "name=conditionalCrossTermValidCatOnly\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8223",
#   "name=crossTermOptionEnumerationItems\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8551",
#   "name=crossTermValidConditionalPresenceItems\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8361",
#   "name=crossTermValidSimple\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8302",
#   "name=getItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8968",
#   "name=crossTermValid\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8674",
#   "name=fieldValidate\nfile=wwpdb/apps/deposit/depui/validation.py\nline=255",
#   "name=get_pickle\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=35",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=29",
#   "name=get_sg_groups_initials\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=123",
#   "name=get_sg_groups_partial_name\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=131",
#   "name=get_full_sg_groups\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=115",
#   "name=get_instances\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8616",
#   "name=putNmolecule\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=171",
#   "name=getDBstatus\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7871",
#   "name=runUpdate\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=178",
#   "name=runInsertUpdateNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=128",
#   "name=isSG\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=184",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/snapshot/UserData.py\nline=18",
#   "name=getRelatedCode\nfile=wwpdb/apps/deposit/depui/snapshot/Related.py\nline=54",
#   "name=getRelatedDB\nfile=wwpdb/apps/deposit/depui/snapshot/Related.py\nline=34",
#   "name=getUserData\nfile=wwpdb/apps/deposit/depui/snapshot/UserData.py\nline=24",
#   "name=validateEmailsInContacts\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6735",
#   "name=get_valid_orcid\nfile=wwpdb/apps/deposit/depui/snapshot/EntryFlags.py\nline=186",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/snapshot/Related.py\nline=29",
#   "name=get_flag\nfile=wwpdb/apps/deposit/depui/snapshot/EntryFlags.py\nline=55",
#   "name=checkEmailsInContacts\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6728",
#   "name=_advancedCheckMenuItemsStateGenerateKeyValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2652",
#   "name=_advancedCheckMenuItemsStateRetrieveItems\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2683",
#   "name=_advancedCheckMenuItemsStateGetCheckInstNum\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2739",
#   "name=_advancedCheckMenuItemsStateEvaluateValues\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2751",
#   "name=_advancedCheckMenuItemsStateGetInstNum\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2587",
#   "name=advancedReturnMenuItemState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2550",
#   "name=validate_assembly_cif_items\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=4123",
#   "name=getDepositPath\nfile=wwpdb/io/locator/PathInfo.py\nline=154",
#   "name=getAssemblyModelFilePath\nfile=wwpdb/io/locator/PathInfo.py\nline=389",
#   "name=isReferenceValid\nfile=wwpdb/io/locator/DataReference.py\nline=697",
#   "name=__getStandardPath\nfile=wwpdb/io/locator/PathInfo.py\nline=512",
#   "name=_merge_cc_dep_info\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=2517",
#   "name=enumerateListHacksByItem\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7467",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=43",
#   "name=updateDatasetIDContext\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=135",
#   "name=updateEntryContext\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=131",
#   "name=deleteCategories\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=266",
#   "name=getAssemblySuggestedFilePath\nfile=wwpdb/io/locator/PathInfo.py\nline=394",
#   "name=saveProgress\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3583",
#   "name=getSupramolecules\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3480",
#   "name=getNmolecule\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=219",
#   "name=getPDBID\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7862",
#   "name=getDBstatusEMDB\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7874",
#   "name=walk\nfile=wwpdb/apps/deposit/depui/emtree.py\nline=91",
#   "name=getEMDBID\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7868",
#   "name=getProgress\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3713",
#   "name=validate_getUploadValidate_merge\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6069",
#   "name=getDepMessageSubjects\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=443",
#   "name=getDiffrnDataType\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3525",
#   "name=transitionContact\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2322",
#   "name=getBMRBID\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7865",
#   "name=progressOverride\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3651",
#   "name=add_node\nfile=wwpdb/apps/deposit/depui/emtree.py\nline=23",
#   "name=get_http_response\nfile=wwpdb/apps/deposit/depui/testfunc.py\nline=17",
#   "name=getAlignState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6424",
#   "name=getLiteProgress\nfile=wwpdb/apps/deposit/depui/dataObject/LiteState.py\nline=183",
#   "name=getProcessProgress\nfile=wwpdb/apps/deposit/depui/dataObject/LiteState.py\nline=220",
#   "name=getMessageSubjects\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=368",
#   "name=saveAlignmentPickle\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6428",
#   "name=getAlignmentPickle\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6434",
#   "name=getSameAuClashes\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2035",
#   "name=getSymmClashes\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2045",
#   "name=addDateIfDep\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7888",
#   "name=getItem\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=48",
#   "name=get_latest_deposit_file\nfile=wwpdb/apps/deposit/depui/upload.py\nline=3732",
#   "name=getUploadValidateEM_report\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6168",
#   "name=getValidationStatus\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=106",
#   "name=get_latest_deposit_file\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9752",
#   "name=remove_category_rows\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9551"
# ]

# %%
# Identify nodes having only one incoming edge
nodes_with_one_incoming_edge = [node for node in G.nodes if G.in_degree(node) == 1]
print(f"Nodes with only one incoming edge: {json.dumps(nodes_with_one_incoming_edge, indent=2)}")
# Out:
# Nodes with only one incoming edge: [
#   "name=__init__\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=29",
#   "name=__init__\nfile=wwpdb/utils/wf/dbapi/DbConnection.py\nline=24",
#   "name=connect\nfile=wwpdb/utils/wf/dbapi/DbConnection.py\nline=84",
#   "name=getObject\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=220",
#   "name=selectRows\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=255",
#   "name=checkId\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=583",
#   "name=makeSqlConstraint\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=104",
#   "name=check_login\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1171",
#   "name=_generateCCDef\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10152",
#   "name=initProgress\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6492",
#   "name=__init__\nfile=wwpdb/io/locator/DataReference.py\nline=65",
#   "name=__init__\nfile=wwpdb/utils/wf/DataValueContainer.py\nline=34",
#   "name=__getInternalFilePath\nfile=wwpdb/io/locator/DataReference.py\nline=971",
#   "name=__getInternalFileNameVersioned\nfile=wwpdb/io/locator/DataReference.py\nline=1008",
#   "name=__getInternalPartitionNumber\nfile=wwpdb/io/locator/DataReference.py\nline=1249",
#   "name=__latestVersion\nfile=wwpdb/io/locator/DataReference.py\nline=1105",
#   "name=check_upload_conditions\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1470",
#   "name=check_em_valid\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2800",
#   "name=save_original_file_name\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1298",
#   "name=check_complexErrors\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2360",
#   "name=assign_map_partitions\nfile=wwpdb/apps/deposit/depui/upload.py\nline=3046",
#   "name=set_page_permissions\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2484",
#   "name=report_em_issues\nfile=wwpdb/apps/deposit/depui/upload.py\nline=3356",
#   "name=reset_ligands_and_status\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2593",
#   "name=remove_old_maps\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10393",
#   "name=check_em_upload\nfile=wwpdb/apps/deposit/depui/upload.py\nline=3142",
#   "name=set_internal_files\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9584",
#   "name=getDBstatus\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=60",
#   "name=populate_em_map_upload\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2927",
#   "name=run_workflows\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2825",
#   "name=get_previous_data_on_reset\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2849",
#   "name=get_em_map_upload\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2916",
#   "name=check_em\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2747",
#   "name=check_related\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1338",
#   "name=populate_em_experiment\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10519",
#   "name=copy_existing_files_to_tempdep\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1543",
#   "name=prepare_onedep_folders\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1515",
#   "name=process_files\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1795",
#   "name=check_block_edit\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2556",
#   "name=copy_from_tempdep_to_deposit\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2610",
#   "name=populate_map\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10556",
#   "name=add_related_info\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2097",
#   "name=get_experiment_types\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1197",
#   "name=addStatus\nfile=wwpdb/apps/deposit/depui/status.py\nline=240",
#   "name=runSelectSQL\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=213",
#   "name=close\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=22",
#   "name=runInsertNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=141",
#   "name=runInsertSQL\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=190",
#   "name=runInsertSQL\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=151",
#   "name=runInsert\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=151",
#   "name=close\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=141",
#   "name=close\nfile=wwpdb/utils/wf/dbapi/DbConnection.py\nline=115",
#   "name=createLongEvent\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=604",
#   "name=getCodes\nfile=wwpdb/apps/deposit/depui/snapshot/Experiments.py\nline=67",
#   "name=runSelect\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=33",
#   "name=getExperiments\nfile=wwpdb/apps/deposit/depui/snapshot/Experiments.py\nline=45",
#   "name=setSessionDataSetId\nfile=wwpdb/io/locator/DataReference.py\nline=565",
#   "name=getCategoriesToUpdate\nfile=wwpdb/apps/deposit/depui/constants.py\nline=2197",
#   "name=get_all_flags\nfile=wwpdb/apps/deposit/depui/snapshot/EntryFlags.py\nline=28",
#   "name=check_upload_complete\nfile=wwpdb/apps/deposit/depui/upload.py\nline=166",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=24",
#   "name=run_process\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=216",
#   "name=get_warning_string\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=88",
#   "name=get_error_string\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=80",
#   "name=process_files\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=142",
#   "name=process_submitted_files\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=131",
#   "name=process_active_types\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=127",
#   "name=process_new_files\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=138",
#   "name=get_submitted_warning\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=194",
#   "name=check_tarball\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=257",
#   "name=check_diffraction\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=423",
#   "name=check_nmr\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=276",
#   "name=check_ec\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=498",
#   "name=check_none_types\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=233",
#   "name=check_pdb\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=475",
#   "name=check_emdb\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=444",
#   "name=is_nmr\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=96",
#   "name=is_ec\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=103",
#   "name=is_diffraction\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=117",
#   "name=get_submitted_file_count\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=135",
#   "name=create_onedep_folder\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1498",
#   "name=clear_out_folder\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1026",
#   "name=does_pickle_exist\nfile=wwpdb/apps/deposit/depui/PickleUtil.py\nline=85",
#   "name=load_from_pickle\nfile=wwpdb/apps/deposit/depui/PickleUtil.py\nline=248",
#   "name=clean_em_software\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9450",
#   "name=is_em_or_ec\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10191",
#   "name=get_original_name_from_db\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10354",
#   "name=update_em_map_file_names\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10199",
#   "name=check_em_map_matches_DB\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10226",
#   "name=removeAllValuesFromInstance\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3042",
#   "name=isNmrUnifiedDeposition\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9908",
#   "name=get_map_where\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10469",
#   "name=parseFileName\nfile=wwpdb/io/locator/PathInfo.py\nline=78",
#   "name=__init__\nfile=wwpdb/io/locator/DataReference.py\nline=145",
#   "name=__init__\nfile=wwpdb/io/locator/DataReference.py\nline=79",
#   "name=get\nfile=wwpdb/io/locator/DataReference.py\nline=170",
#   "name=set\nfile=wwpdb/io/locator/DataReference.py\nline=165",
#   "name=__splitFileName\nfile=wwpdb/io/locator/DataReference.py\nline=176",
#   "name=getFormatTypes\nfile=wwpdb/io/locator/DataReference.py\nline=111",
#   "name=contentTypeExists\nfile=wwpdb/io/locator/DataReference.py\nline=99",
#   "name=getExtensionFormats\nfile=wwpdb/io/locator/DataReference.py\nline=123",
#   "name=runUIhacks\nfile=wwpdb/apps/deposit/depui/upload.py\nline=369",
#   "name=clearUIlock\nfile=wwpdb/apps/deposit/depui/hiddenData/setHidden.py\nline=237",
#   "name=createFileEvent\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=598",
#   "name=update_em_parameters\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1617",
#   "name=calculate_centre_of_mass_for_xray\nfile=wwpdb/apps/deposit/depui/upload.py\nline=334",
#   "name=do_file_action\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1700",
#   "name=check_em_conversion\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1739",
#   "name=__map_sorter\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1809",
#   "name=do_file_merge\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1667",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/hiddenData/setHidden.py\nline=34",
#   "name=runFormatModelCheckWf\nfile=wwpdb/apps/deposit/depui/upload.py\nline=272",
#   "name=decompressAndCopyFile\nfile=wwpdb/apps/deposit/depui/upload.py\nline=775",
#   "name=getSystemFileType\nfile=wwpdb/apps/deposit/depui/upload.py\nline=455",
#   "name=check_file_format\nfile=wwpdb/apps/deposit/depui/upload.py\nline=642",
#   "name=checkNonAscii\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=943",
#   "name=setExternalFilePath\nfile=wwpdb/io/locator/DataReference.py\nline=369",
#   "name=badVersionNumber\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=80",
#   "name=write_EM_parameters\nfile=wwpdb/apps/deposit/depui/upload.py\nline=4153",
#   "name=doComplexConvertWf\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=112",
#   "name=complexLogFile\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=1263",
#   "name=snapshotCreateActionEvent\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=108",
#   "name=createActionEvent\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=610",
#   "name=convertFileEvent\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=592",
#   "name=doEMImageProcessing\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=2329",
#   "name=report_image_errors\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=619",
#   "name=dumpReport\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=716",
#   "name=getProcessPartition\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=516",
#   "name=report_fsc_errors\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=164",
#   "name=collate_errors\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=763",
#   "name=get_original_names\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=127",
#   "name=report_map_errors\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=233",
#   "name=get_file_for_content_type_format\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=97",
#   "name=getPartition\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=482",
#   "name=check_half_map_consistency\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=458",
#   "name=lookup_report_name\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=373",
#   "name=check_contour\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=658",
#   "name=fetch_converted_file\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=576",
#   "name=check_consistency\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=393",
#   "name=get_summary_for_summary_page\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=531",
#   "name=checkIfAscii\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=968",
#   "name=get_coordinate_errors\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=258",
#   "name=get_warnings\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=107",
#   "name=populate_coordinate_warnings\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=84",
#   "name=get_upload_complex_report\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6320",
#   "name=get_sf_errors\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=266",
#   "name=get_errors\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=103",
#   "name=get_structure_factor_report_json_contents\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=48",
#   "name=populate_sf_report\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=71",
#   "name=get_coordinate_warnings\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=119",
#   "name=get_aniso_no_tls\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=111",
#   "name=populate_full_coord_report\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=64",
#   "name=get_method_specific_errors\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=193",
#   "name=populate_coordinate_cell_issues\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=77",
#   "name=populate_coordinate_issues\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=81",
#   "name=populate_coordinate_errors\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=74",
#   "name=populate_coordinate_information\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=87",
#   "name=populate_coord_space_group\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=90",
#   "name=get_sequence_issues\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=124",
#   "name=bracket_at_end_of_polymer\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=131",
#   "name=get_pdb_coordinate_errors\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=159",
#   "name=get_occupancy_issues\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=127",
#   "name=ligands_with_zero_occupancy\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=149",
#   "name=is_diffraction\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=187",
#   "name=itemVisibility\nfile=wwpdb/apps/deposit/depui/hiddenData/setHidden.py\nline=121",
#   "name=createUI\nfile=wwpdb/apps/deposit/depui/precalc/createIDs.py\nline=416",
#   "name=createLigandTags\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=994",
#   "name=readCif\nfile=wwpdb/apps/deposit/depui/precalc/createIDs.py\nline=155",
#   "name=writeCif\nfile=wwpdb/apps/deposit/depui/precalc/createIDs.py\nline=411",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/precalc/createIDs.py\nline=40",
#   "name=scan_cif\nfile=wwpdb/apps/deposit/depui/precalc/createIDs.py\nline=73",
#   "name=updateCIF\nfile=wwpdb/apps/deposit/depui/precalc/createIDs.py\nline=165",
#   "name=getPickleBaseDictionary\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/dictionary_access.py\nline=35",
#   "name=getmmCIFDictionaryFile\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/dictionary_access.py\nline=7",
#   "name=__setup\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/PdbxDict.py\nline=44",
#   "name=getSetInstanceText\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=162",
#   "name=getBlock\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=98",
#   "name=getSetInstanceCount\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=170",
#   "name=getInstance\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=198",
#   "name=__getDataBlock\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=401",
#   "name=__setDataBlock\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=425",
#   "name=getCategoryItemSet\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/PdbxDict.py\nline=98",
#   "name=__bundleInstance\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=282",
#   "name=__getRowValue\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=337",
#   "name=add_extra_information\nfile=wwpdb/apps/deposit/depui/precalc/createIDs.py\nline=147",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=87",
#   "name=writeCif\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=934",
#   "name=add_uploaded_files\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=812",
#   "name=write_out_issues_json\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=744",
#   "name=process_coordinate_file\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=178",
#   "name=prepare_issues_for_json\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=724",
#   "name=scanAtomSite\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=546",
#   "name=addData\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=835",
#   "name=check_extra_categories\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=331",
#   "name=stripContent\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=790",
#   "name=get_polymer_sequences\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=309",
#   "name=get_category_data\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=536",
#   "name=correct_pdbx_refine_id\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=337",
#   "name=check_tls\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=472",
#   "name=check_for_aniso\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=489",
#   "name=checkSoftware\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=396",
#   "name=test_residual_b\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=478",
#   "name=get_cell_symmetry\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=521",
#   "name=checkRefine\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=374",
#   "name=check_depui_status_flags\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=495",
#   "name=checkRefineAndSoftware\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=406",
#   "name=test_occupancy\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=667",
#   "name=getNewDefinition\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=270",
#   "name=test_bfactor\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=698",
#   "name=ExistingInstance\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=213",
#   "name=test_invalid_asym_id\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=650",
#   "name=test_has_tls_group_id\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=645",
#   "name=getFormula\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=241",
#   "name=test_len_asym_id\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=655",
#   "name=getFormulaString\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=769",
#   "name=isWater\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=231",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/precalc/LigandDefinition.py\nline=35",
#   "name=getNewInstance\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=255",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/precalc/LigandInstance.py\nline=23",
#   "name=check_pdbx_refine_tls_group\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=435",
#   "name=check_tls_and_aniso\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=441",
#   "name=check_pdbx_refine_tls\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=410",
#   "name=check_all_tls_categories\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=450",
#   "name=is_unknown_het_in_sequence\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=74",
#   "name=remove_category\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=779",
#   "name=analyse_occupancy_of_ligands\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=714",
#   "name=get_next_pdbx_for_content_type\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=206",
#   "name=postModifyAssembly\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3886",
#   "name=postModifyData\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2220",
#   "name=buildIntegrated\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7040",
#   "name=loadDictionary\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=639",
#   "name=postModifyExptl\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=4436",
#   "name=postModifyMeta\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3764",
#   "name=load_multiple_data_blocks\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxIoUtil.py\nline=103",
#   "name=getBlockList\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=113",
#   "name=get\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/PdbxDictionaryLoader.py\nline=40",
#   "name=crossCategoryItemValidation\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8478",
#   "name=crossTermRegexCheck\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8527",
#   "name=enumerateListHacks\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7502",
#   "name=conditionalCrossTermValidCatOnly\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8223",
#   "name=crossTermOptionEnumerationItems\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8551",
#   "name=crossTermValidConditionalPresenceItems\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8361",
#   "name=crossTermValidOneAtLeast\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8605",
#   "name=getConstReplace\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6963",
#   "name=crossTermValidSimple\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8302",
#   "name=crossTermValidMakeMandatory\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8442",
#   "name=crossTermValidMakeMandatorySubtype\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8403",
#   "name=validate_hacks\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8070",
#   "name=return_allowed_author_list\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=140",
#   "name=fieldValidate\nfile=wwpdb/apps/deposit/depui/validation.py\nline=255",
#   "name=backward_support_for_boundary\nfile=wwpdb/apps/deposit/depui/validation.py\nline=229",
#   "name=get_pickle\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=35",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=29",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=97",
#   "name=read_dictionary\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=38",
#   "name=return_sg_groups\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=103",
#   "name=get_sg_groups_initials\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=123",
#   "name=get_sg_groups_partial_name\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=131",
#   "name=get_full_sg_groups\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=115",
#   "name=return_enumeration_with_detail\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=75",
#   "name=crossTermValidConditionalPresence\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8377",
#   "name=crossTermOptionEnumeration\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8566",
#   "name=get_instances\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8616",
#   "name=getCrossTermValidOneAtLeastItemsAndError\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8598",
#   "name=putNmolecule\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=171",
#   "name=advancedCheckMenuItemsState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2918",
#   "name=setBrainCif\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2332",
#   "name=checkMenuItemsState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2466",
#   "name=runInsertUpdate\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=199",
#   "name=runUpdate\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=178",
#   "name=runInsertUpdateNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=128",
#   "name=isSG\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=184",
#   "name=getRelatedCode\nfile=wwpdb/apps/deposit/depui/snapshot/Related.py\nline=54",
#   "name=getRelatedDB\nfile=wwpdb/apps/deposit/depui/snapshot/Related.py\nline=34",
#   "name=validateEmailsInContacts\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6735",
#   "name=get_valid_orcid\nfile=wwpdb/apps/deposit/depui/snapshot/EntryFlags.py\nline=186",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/snapshot/Related.py\nline=29",
#   "name=get_flag\nfile=wwpdb/apps/deposit/depui/snapshot/EntryFlags.py\nline=55",
#   "name=checkEmailsInContactsCore\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6751",
#   "name=_advancedCheckMenuItemsStateGenerateKeyValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2652",
#   "name=_advancedCheckMenuItemsStateRetrieveItems\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2683",
#   "name=_advancedCheckMenuItemsStateGetCheckInstNum\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2739",
#   "name=_advancedCheckMenuItemsStateFailValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2776",
#   "name=_advancedCheckMenuItemsStateEvaluateLogicState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2794",
#   "name=_advancedCheckMenuItemsStateSetFailstate\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2670",
#   "name=advancedCheckMenuItemsStateFlagsList\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2843",
#   "name=_advancedCheckMenuItemsStateEvaluateValues\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2751",
#   "name=_advancedCheckMenuItemsStateGetValues\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2710",
#   "name=_advancedCheckMenuItemsStateRetrieveSetFieldAndKey\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2628",
#   "name=_advancedCheckMenuItemsStateGetInstNum\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2587",
#   "name=advancedReturnMenuItemState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2550",
#   "name=update_assembly_form\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=4220",
#   "name=save_matrices_from_cif_to_depositor_info\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=4360",
#   "name=save_assembly_to_json\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=4007",
#   "name=validate_assembly_cif_items\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=4123",
#   "name=get_chain_id_for_assembly\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=4079",
#   "name=trim_categories\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=4427",
#   "name=get_matrices_from_string\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=4398",
#   "name=save_assembly_to_cif\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=773",
#   "name=getDepositPath\nfile=wwpdb/io/locator/PathInfo.py\nline=154",
#   "name=getAssemblyModelFilePath\nfile=wwpdb/io/locator/PathInfo.py\nline=389",
#   "name=__getPathWorker\nfile=wwpdb/io/locator/PathInfo.py\nline=530",
#   "name=getVersionIdSearchTarget\nfile=wwpdb/io/locator/DataReference.py\nline=993",
#   "name=isReferenceValid\nfile=wwpdb/io/locator/DataReference.py\nline=697",
#   "name=getContentTypeSearchTarget\nfile=wwpdb/io/locator/DataReference.py\nline=1215",
#   "name=buildValues\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7556",
#   "name=saveToCif\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=708",
#   "name=loadFullCif\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=649",
#   "name=_merge_cc_dep_info\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=2517",
#   "name=enumerateListHacksByItem\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7467",
#   "name=writeFile\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxIoUtil.py\nline=178",
#   "name=check_for_identical_sequences_between_current_and_previous_submission\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=796",
#   "name=get_most_recent_backup\nfile=wwpdb/apps/deposit/depui/PickleUtil.py\nline=117",
#   "name=updateSomeFixedOutput\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=230",
#   "name=updateSomeIdList\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=138",
#   "name=removeSoftware\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=596",
#   "name=putInstance\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=556",
#   "name=deleteCategories\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=266",
#   "name=removeEmptyorganism\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=296",
#   "name=removeHiddenData\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=392",
#   "name=tryfixMissingOrdinals\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=479",
#   "name=getCategoryName\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/PdbxDict.py\nline=113",
#   "name=createCategory\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=531",
#   "name=getAttributeNames\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/PdbxDict.py\nline=122",
#   "name=existsCategory\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=521",
#   "name=remove_trailing_decimel_from_full_matrices\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=4391",
#   "name=getAssemblySuggestedFilePath\nfile=wwpdb/io/locator/PathInfo.py\nline=394",
#   "name=updateAuthorDeposition\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6859",
#   "name=updateTitleDeposition\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6880",
#   "name=updateUserTableContacts\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6901",
#   "name=updateDepositorTable\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6930",
#   "name=codeBasedTags\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6626",
#   "name=getSupramolecules\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3480",
#   "name=getNmolecule\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=219",
#   "name=getPDBID\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7862",
#   "name=updateViewContext\nfile=wwpdb/apps/deposit/depui/views.py\nline=369",
#   "name=load_tree\nfile=wwpdb/apps/deposit/depui/emtree.py\nline=123",
#   "name=getDBstatusEMDB\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7874",
#   "name=get_encoded_depid\nfile=wwpdb/apps/deposit/depui/sas_handling.py\nline=66",
#   "name=getContactAuthsFromPickle\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1014",
#   "name=getValidationFiles\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1581",
#   "name=getHasPressedValidate\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6794",
#   "name=walk\nfile=wwpdb/apps/deposit/depui/emtree.py\nline=91",
#   "name=getEMDBID\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7868",
#   "name=getProgress\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3713",
#   "name=copy_em_3d_fitting_list_from_legacy\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10664",
#   "name=validate_getUploadValidate_merge\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6069",
#   "name=locking_status\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7815",
#   "name=getMessageData\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=867",
#   "name=getUploadStates\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=244",
#   "name=getDepMessageSubjects\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=443",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/emtree.py\nline=13",
#   "name=getDiffrnDataType\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3525",
#   "name=pretty_menu\nfile=wwpdb/apps/deposit/depui/views.py\nline=1169",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/sas_handling.py\nline=27",
#   "name=transitionContact\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2322",
#   "name=getComplete\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3619",
#   "name=getSeqAlignment\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6352",
#   "name=wasUploadOK\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6328",
#   "name=getLigandLiteState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1474",
#   "name=getDataFiles\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2168",
#   "name=getValidDataMmcif\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2054",
#   "name=getBMRBID\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7865",
#   "name=getStatusCodeEMDB\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=816",
#   "name=progressOverride\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3651",
#   "name=add_node\nfile=wwpdb/apps/deposit/depui/emtree.py\nline=23",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/emtree.py\nline=144",
#   "name=add_node_child\nfile=wwpdb/apps/deposit/depui/emtree.py\nline=30",
#   "name=get_children\nfile=wwpdb/apps/deposit/depui/emtree.py\nline=151",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/sas_handling.py\nline=80",
#   "name=get_api_password\nfile=wwpdb/apps/deposit/depui/sas_handling.py\nline=100",
#   "name=get_api_username\nfile=wwpdb/apps/deposit/depui/sas_handling.py\nline=97",
#   "name=get_http_response\nfile=wwpdb/apps/deposit/depui/testfunc.py\nline=17",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/testfunc.py\nline=96",
#   "name=getAlignState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6424",
#   "name=isLigandComplete\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1460",
#   "name=getDepFiles\nfile=wwpdb/apps/deposit/depui/dataObject/DepFiles.py\nline=201",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/dataObject/DepFiles.py\nline=118",
#   "name=whatIsFile\nfile=wwpdb/apps/deposit/depui/dataObject/DepFiles.py\nline=170",
#   "name=getProcessProgress\nfile=wwpdb/apps/deposit/depui/dataObject/LiteState.py\nline=220",
#   "name=isComplete\nfile=wwpdb/apps/deposit/depui/dataObject/LiteState.py\nline=149",
#   "name=getEmail\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3461",
#   "name=getMessageSubjects\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=368",
#   "name=getVariableFromConfigInfo\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=58",
#   "name=getSeqAnnotation\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6466",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/seqAlign/SeqAlign2.py\nline=43",
#   "name=saveAlignmentPickle\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6428",
#   "name=setDataType\nfile=wwpdb/apps/deposit/depui/seqAlign/SeqAlign2.py\nline=120",
#   "name=doAlign\nfile=wwpdb/apps/deposit/depui/seqAlign/SeqAlign2.py\nline=335",
#   "name=isCoordSeqValid\nfile=wwpdb/apps/deposit/depui/seqAlign/SeqAlign2.py\nline=169",
#   "name=getProteinOrNA\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6345",
#   "name=__getReturn\nfile=wwpdb/apps/deposit/depui/seqAlign/SeqAlign2.py\nline=127",
#   "name=_getAlignFormat\nfile=wwpdb/apps/deposit/depui/seqAlign/SeqAlign2.py\nline=413",
#   "name=getAlignmentPickle\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6434",
#   "name=getSameAuClashes\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2035",
#   "name=get_chiral_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1892",
#   "name=get_validate_polymer_linkage\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1705",
#   "name=get_peptide_omega_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1921",
#   "name=get_bond_angle_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1765",
#   "name=get_other_plane_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1850",
#   "name=getSymmClashes\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2045",
#   "name=get_bond_length_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1812",
#   "name=get_solvent_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1953",
#   "name=get_main_chain_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1871",
#   "name=get_coordinate_information\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=273",
#   "name=safeRollStates\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=350",
#   "name=createOldModelStatus\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=272",
#   "name=getValidData\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2094",
#   "name=collate_summaries\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1543",
#   "name=count_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1534",
#   "name=writeFileNoFix\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxIoUtil.py\nline=113",
#   "name=remove_excess_categories\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2380",
#   "name=check_authors\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2458",
#   "name=initilliseDepositDict\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=473",
#   "name=getDBdataValues\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7893",
#   "name=addDateIfDep\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7888",
#   "name=setProgress\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3737",
#   "name=ascii_string\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7946",
#   "name=valueItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7960",
#   "name=get_provided_emdb\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7857",
#   "name=getItem\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=48",
#   "name=deleteLigandState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1470",
#   "name=deleteStateFile\nfile=wwpdb/apps/deposit/depui/dataObject/LiteState.py\nline=115",
#   "name=locate\nfile=wwpdb/apps/deposit/depui/dataObject/LiteState.py\nline=286",
#   "name=update_map_file\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10459",
#   "name=get_latest_deposit_file\nfile=wwpdb/apps/deposit/depui/upload.py\nline=3732",
#   "name=getUploadValidateEM_report\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6168",
#   "name=runWorkflowOnUpload\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=680",
#   "name=getValidationStatus\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=106",
#   "name=create_soft_link\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10681",
#   "name=get_latest_deposit_file\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9752",
#   "name=remove_category_rows\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9551"
# ]

# %%
# # Plot a horizontal bar chart of the in-degree distribution of the top 10 nodes
# import matplotlib.pyplot as plt
# import numpy as np

# # Sort the nodes based on in-degree
# sorted_nodes_by_in_degree = {node: in_degree_centrality[node] for node in sorted(in_degree_centrality, key=in_degree_centrality.get, reverse=True)}

# # Get the top 10 nodes
# top_10_nodes_by_in_degree = list(sorted_nodes_by_in_degree.keys())[:10]
# top_10_nodes_in_degree = [sorted_nodes_by_in_degree[node] for node in top_10_nodes_by_in_degree]

# # Plot the horizontal bar chart
# fig, ax = plt.subplots()
# y_pos = np.arange(len(top_10_nodes_by_in_degree))
# ax.barh(y_pos, top_10_nodes_in_degree, align='center')
# ax.set_yticks(y_pos)
# ax.set_yticklabels(top_10_nodes_by_in_degree, fontsize=8)  # Decrease font size here
# ax.invert_yaxis()
# ax.set_xlabel('In-Degree')

# plt.show()

# %%
# # Plot a horizontal bar chart of the out-degree distribution of the top 10 nodes
# import matplotlib.pyplot as plt
# import numpy as np

# # Sort the nodes based on out-degree
# sorted_nodes_by_out_degree = {node: out_degree_centrality[node] for node in sorted(out_degree_centrality, key=out_degree_centrality.get, reverse=True)}

# # Get the top 10 nodes
# top_10_nodes_by_out_degree = list(sorted_nodes_by_out_degree.keys())[:10]
# top_10_nodes_out_degree = [sorted_nodes_by_out_degree[node] for node in top_10_nodes_by_out_degree]

# # Plot the horizontal bar chart
# fig, ax = plt.subplots()
# y_pos = np.arange(len(top_10_nodes_by_out_degree))
# ax.barh(y_pos, top_10_nodes_out_degree, align='center')
# ax.set_yticks(y_pos)
# ax.set_yticklabels(top_10_nodes_by_out_degree, fontsize=8)  # Adjust font size as needed
# ax.invert_yaxis()
# ax.set_xlabel('Out-Degree')

# plt.show()

# %%
# Identify nodes having only one incoming and one outgoing edge
nodes_with_one_incoming_and_outgoing_edge = [node for node in G.nodes if G.in_degree(node) == 1 and G.out_degree(node) == 1]
print(f"Nodes with only one incoming and one outgoing edge: {json.dumps(nodes_with_one_incoming_and_outgoing_edge, indent=2)}")
# Out:
# Nodes with only one incoming and one outgoing edge: [
#   "name=selectRows\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=255",
#   "name=__init__\nfile=wwpdb/utils/wf/DataValueContainer.py\nline=34",
#   "name=__latestVersion\nfile=wwpdb/io/locator/DataReference.py\nline=1105",
#   "name=check_em_valid\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2800",
#   "name=check_complexErrors\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2360",
#   "name=reset_ligands_and_status\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2593",
#   "name=remove_old_maps\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10393",
#   "name=getDBstatus\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=60",
#   "name=get_em_map_upload\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2916",
#   "name=check_block_edit\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2556",
#   "name=copy_from_tempdep_to_deposit\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2610",
#   "name=close\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=22",
#   "name=runInsertNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=141",
#   "name=runInsertSQL\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=190",
#   "name=runInsertSQL\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=151",
#   "name=runInsert\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=151",
#   "name=close\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=141",
#   "name=createLongEvent\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=604",
#   "name=getCodes\nfile=wwpdb/apps/deposit/depui/snapshot/Experiments.py\nline=67",
#   "name=getExperiments\nfile=wwpdb/apps/deposit/depui/snapshot/Experiments.py\nline=45",
#   "name=get_all_flags\nfile=wwpdb/apps/deposit/depui/snapshot/EntryFlags.py\nline=28",
#   "name=process_new_files\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=138",
#   "name=get_submitted_warning\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=194",
#   "name=check_diffraction\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=423",
#   "name=check_nmr\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=276",
#   "name=check_ec\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=498",
#   "name=create_onedep_folder\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1498",
#   "name=does_pickle_exist\nfile=wwpdb/apps/deposit/depui/PickleUtil.py\nline=85",
#   "name=load_from_pickle\nfile=wwpdb/apps/deposit/depui/PickleUtil.py\nline=248",
#   "name=is_em_or_ec\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10191",
#   "name=update_em_map_file_names\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10199",
#   "name=check_em_map_matches_DB\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10226",
#   "name=isNmrUnifiedDeposition\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9908",
#   "name=createFileEvent\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=598",
#   "name=calculate_centre_of_mass_for_xray\nfile=wwpdb/apps/deposit/depui/upload.py\nline=334",
#   "name=do_file_merge\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1667",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/hiddenData/setHidden.py\nline=34",
#   "name=checkNonAscii\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=943",
#   "name=complexLogFile\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=1263",
#   "name=createActionEvent\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=610",
#   "name=convertFileEvent\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=592",
#   "name=dumpReport\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=716",
#   "name=getProcessPartition\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=516",
#   "name=get_file_for_content_type_format\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=97",
#   "name=fetch_converted_file\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=576",
#   "name=get_coordinate_errors\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=258",
#   "name=get_structure_factor_report_json_contents\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=48",
#   "name=populate_sf_report\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=71",
#   "name=get_method_specific_errors\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=193",
#   "name=populate_coordinate_cell_issues\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=77",
#   "name=get_sequence_issues\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=124",
#   "name=updateCIF\nfile=wwpdb/apps/deposit/depui/precalc/createIDs.py\nline=165",
#   "name=getPickleBaseDictionary\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/dictionary_access.py\nline=35",
#   "name=__getDataBlock\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=401",
#   "name=add_uploaded_files\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=812",
#   "name=write_out_issues_json\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=744",
#   "name=prepare_issues_for_json\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=724",
#   "name=addData\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=835",
#   "name=stripContent\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=790",
#   "name=get_polymer_sequences\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=309",
#   "name=getNewInstance\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=255",
#   "name=get_next_pdbx_for_content_type\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=206",
#   "name=getBlockList\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=113",
#   "name=get\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/PdbxDictionaryLoader.py\nline=40",
#   "name=enumerateListHacks\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7502",
#   "name=conditionalCrossTermValidCatOnly\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8223",
#   "name=crossTermOptionEnumerationItems\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8551",
#   "name=crossTermValidConditionalPresenceItems\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8361",
#   "name=crossTermValidSimple\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8302",
#   "name=fieldValidate\nfile=wwpdb/apps/deposit/depui/validation.py\nline=255",
#   "name=get_pickle\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=35",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=29",
#   "name=get_sg_groups_initials\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=123",
#   "name=get_sg_groups_partial_name\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=131",
#   "name=get_full_sg_groups\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=115",
#   "name=get_instances\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8616",
#   "name=putNmolecule\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=171",
#   "name=runUpdate\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=178",
#   "name=runInsertUpdateNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=128",
#   "name=isSG\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=184",
#   "name=getRelatedCode\nfile=wwpdb/apps/deposit/depui/snapshot/Related.py\nline=54",
#   "name=getRelatedDB\nfile=wwpdb/apps/deposit/depui/snapshot/Related.py\nline=34",
#   "name=validateEmailsInContacts\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6735",
#   "name=get_valid_orcid\nfile=wwpdb/apps/deposit/depui/snapshot/EntryFlags.py\nline=186",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/snapshot/Related.py\nline=29",
#   "name=get_flag\nfile=wwpdb/apps/deposit/depui/snapshot/EntryFlags.py\nline=55",
#   "name=_advancedCheckMenuItemsStateGenerateKeyValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2652",
#   "name=_advancedCheckMenuItemsStateRetrieveItems\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2683",
#   "name=_advancedCheckMenuItemsStateGetCheckInstNum\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2739",
#   "name=_advancedCheckMenuItemsStateEvaluateValues\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2751",
#   "name=_advancedCheckMenuItemsStateGetInstNum\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2587",
#   "name=advancedReturnMenuItemState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2550",
#   "name=validate_assembly_cif_items\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=4123",
#   "name=getDepositPath\nfile=wwpdb/io/locator/PathInfo.py\nline=154",
#   "name=getAssemblyModelFilePath\nfile=wwpdb/io/locator/PathInfo.py\nline=389",
#   "name=isReferenceValid\nfile=wwpdb/io/locator/DataReference.py\nline=697",
#   "name=_merge_cc_dep_info\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=2517",
#   "name=enumerateListHacksByItem\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7467",
#   "name=deleteCategories\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=266",
#   "name=getAssemblySuggestedFilePath\nfile=wwpdb/io/locator/PathInfo.py\nline=394",
#   "name=getSupramolecules\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3480",
#   "name=getNmolecule\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=219",
#   "name=getPDBID\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7862",
#   "name=getDBstatusEMDB\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7874",
#   "name=walk\nfile=wwpdb/apps/deposit/depui/emtree.py\nline=91",
#   "name=getEMDBID\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7868",
#   "name=getProgress\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3713",
#   "name=validate_getUploadValidate_merge\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6069",
#   "name=getDepMessageSubjects\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=443",
#   "name=getDiffrnDataType\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3525",
#   "name=transitionContact\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2322",
#   "name=getBMRBID\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7865",
#   "name=progressOverride\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3651",
#   "name=add_node\nfile=wwpdb/apps/deposit/depui/emtree.py\nline=23",
#   "name=get_http_response\nfile=wwpdb/apps/deposit/depui/testfunc.py\nline=17",
#   "name=getAlignState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6424",
#   "name=getProcessProgress\nfile=wwpdb/apps/deposit/depui/dataObject/LiteState.py\nline=220",
#   "name=getMessageSubjects\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=368",
#   "name=saveAlignmentPickle\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6428",
#   "name=getAlignmentPickle\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6434",
#   "name=getSameAuClashes\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2035",
#   "name=getSymmClashes\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2045",
#   "name=addDateIfDep\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7888",
#   "name=getItem\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=48",
#   "name=get_latest_deposit_file\nfile=wwpdb/apps/deposit/depui/upload.py\nline=3732",
#   "name=getUploadValidateEM_report\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6168",
#   "name=getValidationStatus\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=106",
#   "name=get_latest_deposit_file\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9752",
#   "name=remove_category_rows\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9551"
# ]

# %%
# Given that the graph represents a call stack, identify non-branched paths of deep nested calls
# A non-branched path is a path where each node has only one incoming and one outgoing edge
# Initialize a list to hold all non-branched paths
non_branched_paths = []

# Iterate over nodes with only one outgoing edge to start paths
for start_node in nodes_with_one_outgoing_edge:
    current_path = [start_node]
    current_node = start_node
    
    # Traverse the graph following the non-branched path
    while True:
        # Find the next node if the current node has exactly one outgoing edge and is not an end node
        if current_node in nodes_with_one_incoming_and_outgoing_edge:
            next_node = next(iter(G.successors(current_node)), None)
            if next_node and next_node not in current_path:  # Avoid loops
                current_path.append(next_node)
                current_node = next_node
            else:
                break  # End the path if no next node or loop detected
        else:
            break  # End the path if current node does not meet the criteria
    
    # Save the path if it has more than one node
    if len(current_path) > 1:
        non_branched_paths.append(current_path)

# Print the identified non-branched paths
for i, path in enumerate(non_branched_paths, 1):
    print(f"Path {i}: {json.dumps(path, indent=2)}")
# Out:
# Path 1: [
#   "name=selectRows\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=255",
#   "name=makeSqlConstraint\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=104"
# ]
# Path 2: [
#   "name=__init__\nfile=wwpdb/utils/wf/DataValueContainer.py\nline=34",
#   "name=__init__\nfile=wwpdb/io/locator/DataReference.py\nline=243"
# ]
# Path 3: [
#   "name=__latestVersion\nfile=wwpdb/io/locator/DataReference.py\nline=1105",
#   "name=getReferenceType\nfile=wwpdb/io/locator/DataReference.py\nline=71"
# ]
# Path 4: [
#   "name=check_em_valid\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2800",
#   "name=getUploadValidateEM_report\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6168",
#   "name=getUploadValidateEM\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6162"
# ]
# Path 5: [
#   "name=check_complexErrors\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2360",
#   "name=addStatus\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1324"
# ]
# Path 6: [
#   "name=reset_ligands_and_status\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2593",
#   "name=deleteLigandState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1470"
# ]
# Path 7: [
#   "name=remove_old_maps\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10393",
#   "name=remove_category_rows\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9551",
#   "name=saveToPickle\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6699"
# ]
# Path 8: [
#   "name=getDBstatus\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=60",
#   "name=getStatusCode\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=802"
# ]
# Path 9: [
#   "name=get_em_map_upload\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2916",
#   "name=loadFromPickle\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3547"
# ]
# Path 10: [
#   "name=check_block_edit\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2556",
#   "name=validate_getUploadValidate\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6089"
# ]
# Path 11: [
#   "name=copy_from_tempdep_to_deposit\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2610",
#   "name=ss_create_long_event\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1330"
# ]
# Path 12: [
#   "name=close\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=22",
#   "name=close\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=141",
#   "name=close\nfile=wwpdb/utils/wf/dbapi/DbConnection.py\nline=115"
# ]
# Path 13: [
#   "name=runInsertNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=141",
#   "name=runInsert\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=151",
#   "name=runInsertSQL\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=151",
#   "name=runInsertSQL\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=190",
#   "name=runUpdateSQL\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=193"
# ]
# Path 14: [
#   "name=runInsertSQL\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=190",
#   "name=runUpdateSQL\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=193"
# ]
# Path 15: [
#   "name=runInsertSQL\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=151",
#   "name=runInsertSQL\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=190",
#   "name=runUpdateSQL\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=193"
# ]
# Path 16: [
#   "name=runInsert\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=151",
#   "name=runInsertSQL\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=151",
#   "name=runInsertSQL\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=190",
#   "name=runUpdateSQL\nfile=wwpdb/utils/wf/dbapi/DbCommand.py\nline=193"
# ]
# Path 17: [
#   "name=close\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=141",
#   "name=close\nfile=wwpdb/utils/wf/dbapi/DbConnection.py\nline=115"
# ]
# Path 18: [
#   "name=createLongEvent\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=604",
#   "name=createTimeStamp\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=644"
# ]
# Path 19: [
#   "name=getCodes\nfile=wwpdb/apps/deposit/depui/snapshot/Experiments.py\nline=67",
#   "name=runSelectNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=26"
# ]
# Path 20: [
#   "name=getExperiments\nfile=wwpdb/apps/deposit/depui/snapshot/Experiments.py\nline=45",
#   "name=runSelectNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=26"
# ]
# Path 21: [
#   "name=get_all_flags\nfile=wwpdb/apps/deposit/depui/snapshot/EntryFlags.py\nline=28",
#   "name=runSelectNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=26"
# ]
# Path 22: [
#   "name=process_new_files\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=138",
#   "name=__repr__\nfile=wwpdb/apps/deposit/depui/models.py\nline=205"
# ]
# Path 23: [
#   "name=get_submitted_warning\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=194",
#   "name=get_submitted_file_count\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=135"
# ]
# Path 24: [
#   "name=check_diffraction\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=423",
#   "name=is_diffraction\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=117"
# ]
# Path 25: [
#   "name=check_nmr\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=276",
#   "name=is_nmr\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=96"
# ]
# Path 26: [
#   "name=check_ec\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=498",
#   "name=is_ec\nfile=wwpdb/apps/deposit/depui/check_upload_complete.py\nline=103"
# ]
# Path 27: [
#   "name=create_onedep_folder\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1498",
#   "name=getDir\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=135"
# ]
# Path 28: [
#   "name=does_pickle_exist\nfile=wwpdb/apps/deposit/depui/PickleUtil.py\nline=85",
#   "name=get_pickle_file_name\nfile=wwpdb/apps/deposit/depui/PickleUtil.py\nline=82"
# ]
# Path 29: [
#   "name=load_from_pickle\nfile=wwpdb/apps/deposit/depui/PickleUtil.py\nline=248",
#   "name=load_pickle\nfile=wwpdb/apps/deposit/depui/PickleUtil.py\nline=288"
# ]
# Path 30: [
#   "name=is_em_or_ec\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10191",
#   "name=getDataType\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3510"
# ]
# Path 31: [
#   "name=update_em_map_file_names\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10199",
#   "name=saveListToPickle\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6672"
# ]
# Path 32: [
#   "name=check_em_map_matches_DB\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10226",
#   "name=getDBFiles\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1208"
# ]
# Path 33: [
#   "name=isNmrUnifiedDeposition\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9908",
#   "name=getDataType\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3510"
# ]
# Path 34: [
#   "name=createFileEvent\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=598",
#   "name=createTimeStamp\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=644"
# ]
# Path 35: [
#   "name=calculate_centre_of_mass_for_xray\nfile=wwpdb/apps/deposit/depui/upload.py\nline=334",
#   "name=getDataType\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3510"
# ]
# Path 36: [
#   "name=do_file_merge\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1667",
#   "name=ss_create_long_event\nfile=wwpdb/apps/deposit/depui/upload.py\nline=1330"
# ]
# Path 37: [
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/hiddenData/setHidden.py\nline=34",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/PickleUtil.py\nline=45"
# ]
# Path 38: [
#   "name=checkNonAscii\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=943",
#   "name=checkIfAscii\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=968"
# ]
# Path 39: [
#   "name=complexLogFile\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=1263",
#   "name=getFile\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=117"
# ]
# Path 40: [
#   "name=createActionEvent\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=610",
#   "name=createTimeStamp\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=644"
# ]
# Path 41: [
#   "name=convertFileEvent\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=592",
#   "name=createTimeStamp\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=644"
# ]
# Path 42: [
#   "name=dumpReport\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=716",
#   "name=getLatestMapReportFile\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=700"
# ]
# Path 43: [
#   "name=getProcessPartition\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=516",
#   "name=getPartition\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=482"
# ]
# Path 44: [
#   "name=get_file_for_content_type_format\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=97",
#   "name=getFile\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=117"
# ]
# Path 45: [
#   "name=fetch_converted_file\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=576",
#   "name=get_summary_for_summary_page\nfile=wwpdb/apps/deposit/depui/dataObject/getContentEM.py\nline=531"
# ]
# Path 46: [
#   "name=get_coordinate_errors\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=258",
#   "name=get_coords_issues_json_contents\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=32"
# ]
# Path 47: [
#   "name=get_structure_factor_report_json_contents\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=48",
#   "name=getFile\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=117"
# ]
# Path 48: [
#   "name=populate_sf_report\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=71",
#   "name=get_structure_factor_report_json_contents\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=48",
#   "name=getFile\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=117"
# ]
# Path 49: [
#   "name=get_method_specific_errors\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=193",
#   "name=is_diffraction\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=187"
# ]
# Path 50: [
#   "name=populate_coordinate_cell_issues\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=77",
#   "name=populate_coord_space_group\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=90"
# ]
# Path 51: [
#   "name=get_sequence_issues\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=124",
#   "name=bracket_at_end_of_polymer\nfile=wwpdb/apps/deposit/depui/checks/warnings_and_errors.py\nline=131"
# ]
# Path 52: [
#   "name=updateCIF\nfile=wwpdb/apps/deposit/depui/precalc/createIDs.py\nline=165",
#   "name=add_extra_information\nfile=wwpdb/apps/deposit/depui/precalc/createIDs.py\nline=147"
# ]
# Path 53: [
#   "name=getPickleBaseDictionary\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/dictionary_access.py\nline=35",
#   "name=getDictionaryPath\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/dictionary_access.py\nline=18"
# ]
# Path 54: [
#   "name=__getDataBlock\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=401",
#   "name=__getDataBlockList\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=389"
# ]
# Path 55: [
#   "name=add_uploaded_files\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=812",
#   "name=add_extra_information\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=804"
# ]
# Path 56: [
#   "name=write_out_issues_json\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=744",
#   "name=get_next_pdbx_for_content_type\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=206",
#   "name=getFile\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=117"
# ]
# Path 57: [
#   "name=prepare_issues_for_json\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=724",
#   "name=analyse_occupancy_of_ligands\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=714"
# ]
# Path 58: [
#   "name=addData\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=835",
#   "name=add_extra_information\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=804"
# ]
# Path 59: [
#   "name=stripContent\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=790",
#   "name=remove_category\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=779"
# ]
# Path 60: [
#   "name=get_polymer_sequences\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=309",
#   "name=is_unknown_het_in_sequence\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=74"
# ]
# Path 61: [
#   "name=getNewInstance\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=255",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/precalc/LigandInstance.py\nline=23"
# ]
# Path 62: [
#   "name=get_next_pdbx_for_content_type\nfile=wwpdb/apps/deposit/depui/precalc/createLigandTags.py\nline=206",
#   "name=getFile\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=117"
# ]
# Path 63: [
#   "name=getBlockList\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=113",
#   "name=__getDataBlockList\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py\nline=389"
# ]
# Path 64: [
#   "name=get\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/PdbxDictionaryLoader.py\nline=40",
#   "name=readSerializedDictionary\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/PdbxDictionaryLoader.py\nline=61"
# ]
# Path 65: [
#   "name=enumerateListHacks\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7502",
#   "name=getDataType\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3510"
# ]
# Path 66: [
#   "name=conditionalCrossTermValidCatOnly\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8223",
#   "name=testLimits\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8637"
# ]
# Path 67: [
#   "name=crossTermOptionEnumerationItems\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8551",
#   "name=crossTermOptionEnumeration\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8566"
# ]
# Path 68: [
#   "name=crossTermValidConditionalPresenceItems\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8361",
#   "name=crossTermValidConditionalPresence\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8377"
# ]
# Path 69: [
#   "name=crossTermValidSimple\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8302",
#   "name=testLimits\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8637"
# ]
# Path 70: [
#   "name=fieldValidate\nfile=wwpdb/apps/deposit/depui/validation.py\nline=255",
#   "name=backward_support_for_boundary\nfile=wwpdb/apps/deposit/depui/validation.py\nline=229"
# ]
# Path 71: [
#   "name=get_pickle\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=35",
#   "name=getPickleDictionary\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/dictionary_access.py\nline=27"
# ]
# Path 72: [
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=29",
#   "name=get_pickle\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=35",
#   "name=getPickleDictionary\nfile=wwpdb/apps/deposit/depui/mmcif_dictionary/dictionary_access.py\nline=27"
# ]
# Path 73: [
#   "name=get_sg_groups_initials\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=123",
#   "name=return_enumeration\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=60"
# ]
# Path 74: [
#   "name=get_sg_groups_partial_name\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=131",
#   "name=return_enumeration\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=60"
# ]
# Path 75: [
#   "name=get_full_sg_groups\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=115",
#   "name=return_enumeration_with_detail\nfile=wwpdb/apps/deposit/depui/allowed_authors.py\nline=75"
# ]
# Path 76: [
#   "name=get_instances\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8616",
#   "name=get_category_item_values\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7711"
# ]
# Path 77: [
#   "name=putNmolecule\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=171",
#   "name=runInsertUpdateNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=128",
#   "name=runInsertUpdate\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=199"
# ]
# Path 78: [
#   "name=runUpdate\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=178",
#   "name=runUpdateSQL\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=172"
# ]
# Path 79: [
#   "name=runInsertUpdateNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=128",
#   "name=runInsertUpdate\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=199"
# ]
# Path 80: [
#   "name=isSG\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=184",
#   "name=runSelectNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=26"
# ]
# Path 81: [
#   "name=getRelatedCode\nfile=wwpdb/apps/deposit/depui/snapshot/Related.py\nline=54",
#   "name=runSelectNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=26"
# ]
# Path 82: [
#   "name=getRelatedDB\nfile=wwpdb/apps/deposit/depui/snapshot/Related.py\nline=34",
#   "name=runSelectNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=26"
# ]
# Path 83: [
#   "name=validateEmailsInContacts\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6735",
#   "name=checkEmailsInContacts\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6728"
# ]
# Path 84: [
#   "name=get_valid_orcid\nfile=wwpdb/apps/deposit/depui/snapshot/EntryFlags.py\nline=186",
#   "name=get_flag\nfile=wwpdb/apps/deposit/depui/snapshot/EntryFlags.py\nline=55",
#   "name=runSelectNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=26"
# ]
# Path 85: [
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/snapshot/Related.py\nline=29",
#   "name=__init__\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=13"
# ]
# Path 86: [
#   "name=get_flag\nfile=wwpdb/apps/deposit/depui/snapshot/EntryFlags.py\nline=55",
#   "name=runSelectNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=26"
# ]
# Path 87: [
#   "name=_advancedCheckMenuItemsStateGenerateKeyValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2652",
#   "name=fetchItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8833"
# ]
# Path 88: [
#   "name=_advancedCheckMenuItemsStateRetrieveItems\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2683",
#   "name=getCategoryItems\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7633"
# ]
# Path 89: [
#   "name=_advancedCheckMenuItemsStateGetCheckInstNum\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2739",
#   "name=_advancedCheckMenuItemsStateGetInstNum\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2587",
#   "name=get_category_item_values\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7711"
# ]
# Path 90: [
#   "name=_advancedCheckMenuItemsStateEvaluateValues\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2751",
#   "name=advancedReturnMenuItemState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2550",
#   "name=fetchItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8833"
# ]
# Path 91: [
#   "name=_advancedCheckMenuItemsStateGetInstNum\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2587",
#   "name=get_category_item_values\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7711"
# ]
# Path 92: [
#   "name=advancedReturnMenuItemState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2550",
#   "name=fetchItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8833"
# ]
# Path 93: [
#   "name=validate_assembly_cif_items\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=4123",
#   "name=validateInstance\nfile=wwpdb/apps/deposit/depui/validation.py\nline=22"
# ]
# Path 94: [
#   "name=getDepositPath\nfile=wwpdb/io/locator/PathInfo.py\nline=154",
#   "name=getDirPath\nfile=wwpdb/io/locator/PathInfo.py\nline=432"
# ]
# Path 95: [
#   "name=getAssemblyModelFilePath\nfile=wwpdb/io/locator/PathInfo.py\nline=389",
#   "name=__getStandardPath\nfile=wwpdb/io/locator/PathInfo.py\nline=512"
# ]
# Path 96: [
#   "name=isReferenceValid\nfile=wwpdb/io/locator/DataReference.py\nline=697",
#   "name=__isInternalReferenceValid\nfile=wwpdb/io/locator/DataReference.py\nline=784"
# ]
# Path 97: [
#   "name=_merge_cc_dep_info\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=2517",
#   "name=getFile\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=117"
# ]
# Path 98: [
#   "name=enumerateListHacksByItem\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7467",
#   "name=getExperiments\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=526"
# ]
# Path 99: [
#   "name=deleteCategories\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=266",
#   "name=getStatusCode\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=802"
# ]
# Path 100: [
#   "name=getAssemblySuggestedFilePath\nfile=wwpdb/io/locator/PathInfo.py\nline=394",
#   "name=__getStandardPath\nfile=wwpdb/io/locator/PathInfo.py\nline=512"
# ]
# Path 101: [
#   "name=getSupramolecules\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3480",
#   "name=fetchItemLength\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8709"
# ]
# Path 102: [
#   "name=getNmolecule\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=219",
#   "name=runSelectNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=26"
# ]
# Path 103: [
#   "name=getPDBID\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7862",
#   "name=getAccID\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7829"
# ]
# Path 104: [
#   "name=getDBstatusEMDB\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7874",
#   "name=getStatusCodeEMDB\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=816"
# ]
# Path 105: [
#   "name=walk\nfile=wwpdb/apps/deposit/depui/emtree.py\nline=91",
#   "name=get_children\nfile=wwpdb/apps/deposit/depui/emtree.py\nline=151"
# ]
# Path 106: [
#   "name=getEMDBID\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7868",
#   "name=getAccID\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7829"
# ]
# Path 107: [
#   "name=getProgress\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3713",
#   "name=progressOverride\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3651",
#   "name=load_pickle\nfile=wwpdb/apps/deposit/depui/PickleUtil.py\nline=288"
# ]
# Path 108: [
#   "name=validate_getUploadValidate_merge\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6069",
#   "name=getDir\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=135"
# ]
# Path 109: [
#   "name=getDepMessageSubjects\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=443",
#   "name=getMessageSubjects\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=368",
#   "name=getVariableFromConfigInfo\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=58"
# ]
# Path 110: [
#   "name=getDiffrnDataType\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3525",
#   "name=getExperiments\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=526"
# ]
# Path 111: [
#   "name=transitionContact\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2322",
#   "name=fetchItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8833"
# ]
# Path 112: [
#   "name=getBMRBID\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7865",
#   "name=getAccID\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7829"
# ]
# Path 113: [
#   "name=progressOverride\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3651",
#   "name=load_pickle\nfile=wwpdb/apps/deposit/depui/PickleUtil.py\nline=288"
# ]
# Path 114: [
#   "name=add_node\nfile=wwpdb/apps/deposit/depui/emtree.py\nline=23",
#   "name=__init__\nfile=wwpdb/apps/deposit/depui/emtree.py\nline=144"
# ]
# Path 115: [
#   "name=get_http_response\nfile=wwpdb/apps/deposit/depui/testfunc.py\nline=17",
#   "name=updateViewContext\nfile=wwpdb/apps/deposit/depui/views.py\nline=369"
# ]
# Path 116: [
#   "name=getAlignState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6424",
#   "name=getAlignmentPickle\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6434",
#   "name=load_pickle\nfile=wwpdb/apps/deposit/depui/PickleUtil.py\nline=288"
# ]
# Path 117: [
#   "name=getProcessProgress\nfile=wwpdb/apps/deposit/depui/dataObject/LiteState.py\nline=220",
#   "name=getFile\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=117"
# ]
# Path 118: [
#   "name=getMessageSubjects\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=368",
#   "name=getVariableFromConfigInfo\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=58"
# ]
# Path 119: [
#   "name=saveAlignmentPickle\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6428",
#   "name=save_pickle\nfile=wwpdb/apps/deposit/depui/PickleUtil.py\nline=312"
# ]
# Path 120: [
#   "name=getAlignmentPickle\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6434",
#   "name=load_pickle\nfile=wwpdb/apps/deposit/depui/PickleUtil.py\nline=288"
# ]
# Path 121: [
#   "name=getSameAuClashes\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2035",
#   "name=get_clashes\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1980"
# ]
# Path 122: [
#   "name=getSymmClashes\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2045",
#   "name=get_clashes\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1980"
# ]
# Path 123: [
#   "name=addDateIfDep\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7888",
#   "name=getStatusCode\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=802"
# ]
# Path 124: [
#   "name=getItem\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=48",
#   "name=runSelectNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=26"
# ]
# Path 125: [
#   "name=get_latest_deposit_file\nfile=wwpdb/apps/deposit/depui/upload.py\nline=3732",
#   "name=getFile\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=117"
# ]
# Path 126: [
#   "name=getUploadValidateEM_report\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6168",
#   "name=getUploadValidateEM\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6162"
# ]
# Path 127: [
#   "name=getValidationStatus\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=106",
#   "name=runSelectSQL\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=195"
# ]
# Path 128: [
#   "name=get_latest_deposit_file\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9752",
#   "name=getFile\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=117"
# ]
# Path 129: [
#   "name=remove_category_rows\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9551",
#   "name=saveToPickle\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6699"
# ]

# %%
# # Identify the nodes whose "name" attribute is in camel case
# camel_case_nodes = [node for node in nodes if is_camel_case(extract_node_attributes(node)[0]) or has_uppercase(extract_node_attributes(node)[0])]
# # camel_case_nodes = [
# #     "name=__addMilestoneVariants\nfile=/path/to/file.py\nline=23",
# #     "name=getConfigDictionary\nfile=/path/to/another_file.py\nline=45"
# # ]
# print(f"Nodes with 'name' attribute in camel case: {json.dumps(camel_case_nodes, indent=2)}")
# print(f"Number of nodes with 'name' attribute in camel case: {len(camel_case_nodes)}")

# # Suggest snake case names for the nodes with camel case names
# suggested_names = []
# for node in camel_case_nodes:
#     name, file, line = extract_node_attributes(node)
#     if name is not None:  # Check if name is not None
#         suggested_names.append({
#             "file": file,
#             "line": line,
#             "original_name": name,
#             "suggested_name": suggest_snake_case_name(name)
#         })

# print(f"Suggested snake case names: {json.dumps(suggested_names, indent=2)}")
# print(f"Number of nodes with camel case names: {len(camel_case_nodes)}")

# %%
# # Filter only the suggested names from "wwpdb/apps/deposit/depui/upload.py"
# filtered_suggested_names = [suggestion for suggestion in suggested_names if suggestion["file"] == "wwpdb/apps/deposit/depui/upload.py"]
# print(f"Suggested snake case names in 'wwpdb/apps/deposit/depui/upload.py': {json.dumps(filtered_suggested_names, indent=2)}")
# print(f"Number of nodes with camel case names in 'wwpdb/apps/deposit/depui/upload.py': {len(filtered_suggested_names)}")

# %%
# # Filter only the suggested names from "wwpdb/apps/deposit/depui/dataObject/getContentEM.py"
# filtered_suggested_names = [suggestion for suggestion in suggested_names if suggestion["file"] == "wwpdb/apps/deposit/depui/dataObject/getContentEM.py"]
# print(f"Suggested snake case names in 'wwpdb/apps/deposit/depui/dataObject/getContentEM.py': {json.dumps(filtered_suggested_names, indent=2)}")
# print(f"Number of nodes with camel case names in 'wwpdb/apps/deposit/depui/dataObject/getContentEM.py': {len(filtered_suggested_names)}")

# %%
# # Filter only the suggested names from "wwpdb/apps/deposit/depui/apilayer.py"
# filtered_suggested_names = [suggestion for suggestion in suggested_names if suggestion["file"] == "wwpdb/apps/deposit/depui/apilayer.py"]
# print(f"Suggested snake case names in 'wwpdb/apps/deposit/depui/apilayer.py': {json.dumps(filtered_suggested_names, indent=2)}")
# print(f"Number of nodes with camel case names in 'wwpdb/apps/deposit/depui/apilayer.py': {len(filtered_suggested_names)}")

# %%
# import json
# from networkx.algorithms import community

# # Assuming G is your graph object
# communities = [list(c) for c in community.asyn_lpa_communities(G)]
# print("Communities:", json.dumps(communities, indent=2))

# %%
# # Calculate in-degree and out-degree centrality
# in_degree_centrality = nx.in_degree_centrality(G)
# out_degree_centrality = nx.out_degree_centrality(G)

# # Print a sample of the results
# print("In-Degree Centrality:", json.dumps(sorted(in_degree_centrality.items(), key=lambda x: x[1], reverse=True), indent=2))
# print("Out-Degree Centrality:", json.dumps(sorted(out_degree_centrality.items(), key=lambda x: x[1], reverse=True), indent=2))

# %%
# Find cycles in the graph
cycles = list(nx.simple_cycles(G))
# print("Cycles found:", cycles)  # Print a sample of found cycles
for i, cycle in enumerate(cycles, 1):
    print(f"Cycle {i}: {json.dumps(cycle, indent=2)}")
# Out:
# Cycle 1: [
#   "name=update_recursive\nfile=wwpdb/apps/deposit/depui/upload.py\nline=3363"
# ]
# Cycle 2: [
#   "name=getItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8968"
# ]
# Cycle 3: [
#   "name=returnMenuItemsState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2388"
# ]
# Cycle 4: [
#   "name=mergeData\nfile=wwpdb/apps/deposit/depui/FileConversion.py\nline=2445",
#   "name=loadFullCif\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=649",
#   "name=loadFromCif\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=666",
#   "name=postModifyAssembly\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3886",
#   "name=update_assembly_form\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=4220",
#   "name=save_assembly_to_cif\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=773"
# ]

# %%
# import json
# import networkx as nx

# # Assuming G is your graph object
# strongly_connected_components = [list(comp) for comp in nx.strongly_connected_components(G)]
# weakly_connected_components = [list(comp) for comp in nx.weakly_connected_components(G)]

# print("Strongly Connected Components:", json.dumps(sorted(strongly_connected_components, key=len, reverse=True), indent=2))
# print("Weakly Connected Components:", json.dumps(sorted(weakly_connected_components, key=len, reverse=True), indent=2))

# %%
betweenness_centrality = nx.betweenness_centrality(G)
print("Betweenness Centrality:", json.dumps(sorted(betweenness_centrality.items(), key=lambda x: x[1], reverse=True)[:5], indent=2))
# Out:
# Betweenness Centrality: [
#   [
#     "name=updateViewContext\nfile=wwpdb/apps/deposit/depui/views.py\nline=369",
#     0.0038517953870852244
#   ],
#   [
#     "name=loadFromCif\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=666",
#     0.0036618042802859683
#   ],
#   [
#     "name=get_http_response\nfile=wwpdb/apps/deposit/depui/testfunc.py\nline=17",
#     0.003236778582400702
#   ],
#   [
#     "name=getFile\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=117",
#     0.0027763340763583303
#   ],
#   [
#     "name=get_invalid_tags\nfile=wwpdb/apps/deposit/depui/testfunc.py\nline=41",
#     0.0026386049609430644
#   ]
# ]

# %%
# clustering_coefficient = nx.clustering(nx.Graph(G))
# print("Clustering Coefficient:", json.dumps(sorted(clustering_coefficient.items(), key=lambda x: x[1], reverse=True), indent=2))

# %%
# # %pip install python-louvain
# import community as community_louvain

# partition = community_louvain.best_partition(nx.Graph(G))
# print("Community Partition:", json.dumps(dict(sorted(partition.items(), key=lambda x: x[1])), indent=2))

# %%
# import matplotlib.pyplot as plt

# # Draw the graph in a circular layout color-coded by the partition
# plt.figure(figsize=(10, 10))
# # pos = nx.circular_layout(G)
# # nx.draw(G, pos, with_labels=False, node_size=50, font_size=8)
# # plt.show()

# # Draw the graph in a circular layout color-coded by the partition
# # pos = nx.circular_layout(G)
# # pos = nx.spring_layout(G)
# pos = nx.spectral_layout(G)
# cmap = plt.get_cmap("tab20")
# node_colors = [cmap(partition[node] % 20) for node in G.nodes]
# nx.draw(G, pos, node_color=node_colors, with_labels=False)
# plt.show()

# %%
# # Assuming `G` is your dependency graph
# # G = nx.DiGraph()
# analysis_results = analyze_dependency_graph(G) # FIXME: Use the isolate examples above to improve the function and get better results
# print(analysis_results)

# %%
import seaborn as sns
import networkx as nx
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Assuming G is your graph
# Get the adjacency matrix of the graph
adj_matrix = nx.to_numpy_array(G)

# Apply a Gaussian filter to smooth the adjacency matrix
smoothed_adj_matrix = gaussian_filter(adj_matrix, sigma=1)  # Adjust sigma as needed

# Plot the cluster map with the smoothed matrix
clustermap = sns.clustermap(smoothed_adj_matrix, cmap='viridis', figsize=(10, 10))

# Access the main heatmap axes
heatmap_ax = clustermap.ax_heatmap

# Set labels for the X and Y axes
heatmap_ax.set_xlabel('Target Nodes (Incoming Edges)')
heatmap_ax.set_ylabel('Source Nodes (Outgoing Edges)')

plt.show()

# %%
# import numpy as np
# from scipy.cluster.hierarchy import linkage, fcluster
# from scipy.spatial.distance import pdist, squareform
# from sklearn.metrics import silhouette_score
# import matplotlib.pyplot as plt

# # Assuming adj_matrix is your adjacency matrix from the directed graph G
# # Compute the distance matrix for the callee side (columns of adj_matrix)
# distance_matrix = squareform(pdist(adj_matrix.T, 'euclidean'))

# # Apply single linkage clustering
# Z = linkage(distance_matrix, 'single')

# # Determine the optimal number of clusters
# # This part depends on whether you want to use the elbow method or silhouette score

# # For silhouette score (as it's more straightforward for demonstration)
# # Try a range of cluster numbers, calculate silhouette scores, and pick the best
# silhouette_scores = []
# for n_clusters in range(2, min(len(distance_matrix), 11)):  # Adjust the range as needed
#     labels = fcluster(Z, n_clusters, criterion='maxclust')
#     score = silhouette_score(distance_matrix, labels, metric='precomputed')
#     silhouette_scores.append(score)

# # Plot silhouette scores to find the optimal number of clusters
# plt.plot(range(2, min(len(distance_matrix), 11)), silhouette_scores)
# plt.xlabel('Number of Clusters')
# plt.ylabel('Silhouette Score')
# plt.title('Silhouette Score Method')
# plt.show()

# # Choose the number of clusters with the highest silhouette score
# optimal_clusters = 2 + silhouette_scores.index(max(silhouette_scores))
# print(f'Optimal number of clusters: {optimal_clusters}')

# # Cluster the nodes with the optimal number of clusters
# final_labels = fcluster(Z, optimal_clusters, criterion='maxclust')
# print(f'Final cluster labels: {final_labels}')

# %%
# import numpy as np
# from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
# from scipy.spatial.distance import pdist, squareform
# import matplotlib.pyplot as plt

# # Assuming adj_matrix is your adjacency matrix from the directed graph G
# # Compute the distance matrix for the callee side (columns of adj_matrix)
# distance_matrix = squareform(pdist(adj_matrix.T, 'euclidean'))

# # Apply single linkage clustering
# Z = linkage(distance_matrix, 'single')

# # Determine the optimal number of clusters using the elbow method
# # Calculate the within-cluster sum of squares (WCSS) for different numbers of clusters
# last = Z[-10:, 2]  # Take the last 10 merged clusters
# last_rev = last[::-1]  # Reverse the list to have the largest jumps at the beginning
# idxs = np.arange(1, len(last) + 1)
# plt.plot(idxs, last_rev)

# acceleration = np.diff(last, 2)  # 2nd derivative of the distances
# acceleration_rev = acceleration[::-1]
# plt.plot(idxs[:-2] + 1, acceleration_rev)
# plt.show()

# k = acceleration_rev.argmax() + 2  # if idx 0 is the max of this we want 2 clusters
# print(f'Optimal number of clusters: {k}')

# # Cluster the nodes with the optimal number of clusters
# final_labels = fcluster(Z, k, criterion='maxclust')
# print(f'Final cluster labels: {final_labels}')

# %%
# import numpy as np
# from scipy.cluster.hierarchy import dendrogram, linkage
# from matplotlib import pyplot as plt

# # Assuming 'distance_matrix' is already computed as shown in previous examples
# # Perform hierarchical clustering
# Z = linkage(distance_matrix, 'single')

# # Plot the dendrogram
# plt.figure(figsize=(10, 7))
# dendrogram(
#     Z,
#     truncate_mode='lastp',  # show only the last p merged clusters
#     p=7,  # show only the last 7 merged clusters
#     leaf_rotation=90.,
#     leaf_font_size=12.,
#     show_contracted=True,  # to get a distribution impression in truncated branches
# )

# plt.title('Hierarchical Clustering Dendrogram (truncated)')
# plt.xlabel('cluster size')
# plt.ylabel('distance')

# # Adding a horizontal line to show the cut for the optimal number of clusters
# # plt.axhline(y=distance_threshold, c='k')  # 'distance_threshold' needs to be defined based on your clustering

# # Find the largest distance that forms exactly 7 clusters
# # This is a heuristic approach to estimate a good distance threshold

# # Number of clusters you want
# desired_clusters = 7

# # Inspect the last few merges until we have just fewer than desired clusters
# for i in range(1, len(Z)):
#     num_clusters = len(Z) + 1 - i
#     if num_clusters <= desired_clusters:
#         distance_threshold = Z[-i, 2]
#         break

# print(f"Estimated distance threshold for {desired_clusters} clusters: {distance_threshold}")

# # Now use this distance_threshold in your plot
# plt.axhline(y=distance_threshold, c='k')
# plt.show()

# plt.show()

# %%
# import json
# from scipy.cluster.hierarchy import fcluster

# # Assuming 'Z' is your linkage matrix
# clusters = fcluster(Z, 7, criterion='maxclust')

# # Organize nodes into clusters, converting cluster_id to int
# cluster_dict = {}
# for node_index, cluster_id in enumerate(clusters):
#     cluster_id = int(cluster_id)  # Convert to Python native int
#     if cluster_id not in cluster_dict:
#         cluster_dict[cluster_id] = []
#     cluster_dict[cluster_id].append(node_index)

# # Convert to JSON string with indentation of 2
# json_clusters = json.dumps(cluster_dict, indent=2)

# print(json_clusters)

# %%
# import json
# from scipy.cluster.hierarchy import fcluster
# import networkx as nx

# # Assuming 'Z' is your linkage matrix
# clusters = fcluster(Z, 7, criterion='maxclust')

# # Assuming 'G' is your graph object
# # Extract node labels from the graph G
# node_labels = list(G.nodes)

# # Organize nodes into clusters, converting cluster_id to int and using node labels from G
# cluster_dict = {}
# for node_index, cluster_id in enumerate(clusters):
#     cluster_id = int(cluster_id)  # Convert to Python native int
#     node_label = node_labels[node_index]  # Get the label for the current node from G
#     if cluster_id not in cluster_dict:
#         cluster_dict[cluster_id] = []
#     cluster_dict[cluster_id].append(node_label)  # Use node label instead of index

# # Convert to JSON string with indentation of 2
# json_clusters = json.dumps(cluster_dict, indent=2)

# print(json_clusters)

# %%
import re
import json

def parse_node_name(node):
    """Extracts name, file, and line from the node string."""
    match = re.search(r'name=(.+?)\s+file=(.+?)\s+line=(\d+)', node, re.DOTALL)
    if match:
        return match.group(1).strip(), match.group(2).strip(), int(match.group(3).strip())
    return node.strip(), "Unknown", 0  # Default if parsing fails

def export_to_cypher(graph):
    cypher_statements = []

    # Create nodes with separate properties
    for node in graph.nodes():
        name, file, line = parse_node_name(node)
        node_label = "Node"
        cypher_statements.append(f"CREATE (:Node {{name: {json.dumps(name)}, file: {json.dumps(file)}, line: {line}}});")

    # Create relationships with proper matching
    for source, target in graph.edges():
        src_name, src_file, src_line = parse_node_name(source)
        tgt_name, tgt_file, tgt_line = parse_node_name(target)

        cypher_statements.append(f"""
            MATCH (a:Node {{name: {json.dumps(src_name)}, file: {json.dumps(src_file)}, line: {src_line}}}),
                  (b:Node {{name: {json.dumps(tgt_name)}, file: {json.dumps(tgt_file)}, line: {tgt_line}}})
            CREATE (a)-[:DEPENDS_ON]->(b);
        """)

    return "\n".join(cypher_statements)


cypher_output = export_to_cypher(G)
print(cypher_output)
# Out:
# CREATE (:Node {name: "__init__", file: "wwpdb/utils/wf/dbapi/WfDbApi.py", line: 68});
# CREATE (:Node {name: "__init__", file: "wwpdb/utils/wf/dbapi/DbCommand.py", line: 29});
# CREATE (:Node {name: "__init__", file: "wwpdb/utils/wf/dbapi/DbConnection.py", line: 24});
# CREATE (:Node {name: "connect", file: "wwpdb/utils/wf/dbapi/DbConnection.py", line: 84});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/upload.py", line: 1099});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/FileConversion.py", line: 57});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 27});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/snapshot/Snapshot.py", line: 148});
# CREATE (:Node {name: "getObject", file: "wwpdb/utils/wf/dbapi/WfDbApi.py", line: 220});
# CREATE (:Node {name: "selectRows", file: "wwpdb/utils/wf/dbapi/DbCommand.py", line: 255});
# CREATE (:Node {name: "checkId", file: "wwpdb/utils/wf/dbapi/WfDbApi.py", line: 583});
# CREATE (:Node {name: "makeSqlConstraint", file: "wwpdb/utils/wf/dbapi/DbCommand.py", line: 104});
# CREATE (:Node {name: "exist", file: "wwpdb/utils/wf/dbapi/WfDbApi.py", line: 593});
# CREATE (:Node {name: "check_login", file: "wwpdb/apps/deposit/depui/upload.py", line: 1171});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/snapshot/OtherData.py", line: 42});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/PickleUtil.py", line: 45});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 148});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/wf_engine/engine/dbAPI.py", line: 13});
# CREATE (:Node {name: "_generateCCDef", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 10152});
# CREATE (:Node {name: "saveToPickle", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 6699});
# CREATE (:Node {name: "initProgress", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 6492});
# CREATE (:Node {name: "getUiReqs", file: "wwpdb/apps/deposit/depui/constants.py", line: 379});
# CREATE (:Node {name: "getCifFileName", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2173});
# CREATE (:Node {name: "get_pickle_file_name", file: "wwpdb/apps/deposit/depui/PickleUtil.py", line: 82});
# CREATE (:Node {name: "loadFromCif", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 666});
# CREATE (:Node {name: "__init__", file: "wwpdb/io/locator/DataReference.py", line: 243});
# CREATE (:Node {name: "__init__", file: "wwpdb/io/locator/DataReference.py", line: 65});
# CREATE (:Node {name: "__init__", file: "wwpdb/utils/wf/DataValueContainer.py", line: 34});
# CREATE (:Node {name: "__init__", file: "wwpdb/utils/wf/DataSelector.py", line: 35});
# CREATE (:Node {name: "setVersionId", file: "wwpdb/io/locator/DataReference.py", line: 489});
# CREATE (:Node {name: "setStorageType", file: "wwpdb/io/locator/DataReference.py", line: 464});
# CREATE (:Node {name: "setWorkflowInstanceId", file: "wwpdb/io/locator/DataReference.py", line: 543});
# CREATE (:Node {name: "getFilePathReference", file: "wwpdb/io/locator/DataReference.py", line: 735});
# CREATE (:Node {name: "setDepositionDataSetId", file: "wwpdb/io/locator/DataReference.py", line: 521});
# CREATE (:Node {name: "setContentTypeAndFormat", file: "wwpdb/io/locator/DataReference.py", line: 414});
# CREATE (:Node {name: "__isInteger", file: "wwpdb/io/locator/DataReference.py", line: 512});
# CREATE (:Node {name: "setReferenceType", file: "wwpdb/io/locator/DataReference.py", line: 68});
# CREATE (:Node {name: "__isInternalReferenceValid", file: "wwpdb/io/locator/DataReference.py", line: 784});
# CREATE (:Node {name: "getReferenceType", file: "wwpdb/io/locator/DataReference.py", line: 71});
# CREATE (:Node {name: "__getInternalFilePath", file: "wwpdb/io/locator/DataReference.py", line: 971});
# CREATE (:Node {name: "__getInternalPath", file: "wwpdb/io/locator/DataReference.py", line: 870});
# CREATE (:Node {name: "__getInternalFileNameVersioned", file: "wwpdb/io/locator/DataReference.py", line: 1008});
# CREATE (:Node {name: "__getInternalPartitionNumber", file: "wwpdb/io/locator/DataReference.py", line: 1249});
# CREATE (:Node {name: "__getInternalFileNameBase", file: "wwpdb/io/locator/DataReference.py", line: 915});
# CREATE (:Node {name: "__latestVersion", file: "wwpdb/io/locator/DataReference.py", line: 1105});
# CREATE (:Node {name: "getPartitionNumberSearchTarget", file: "wwpdb/io/locator/DataReference.py", line: 1181});
# CREATE (:Node {name: "run_sandboxed", file: "wwpdb/apps/deposit/depui/upload.py", line: 3410});
# CREATE (:Node {name: "check_upload_conditions", file: "wwpdb/apps/deposit/depui/upload.py", line: 1470});
# CREATE (:Node {name: "check_em_valid", file: "wwpdb/apps/deposit/depui/upload.py", line: 2800});
# CREATE (:Node {name: "save_original_file_name", file: "wwpdb/apps/deposit/depui/upload.py", line: 1298});
# CREATE (:Node {name: "check_complexErrors", file: "wwpdb/apps/deposit/depui/upload.py", line: 2360});
# CREATE (:Node {name: "assign_map_partitions", file: "wwpdb/apps/deposit/depui/upload.py", line: 3046});
# CREATE (:Node {name: "addStatus", file: "wwpdb/apps/deposit/depui/upload.py", line: 1324});
# CREATE (:Node {name: "validate_getUploadValidate", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 6089});
# CREATE (:Node {name: "set_page_permissions", file: "wwpdb/apps/deposit/depui/upload.py", line: 2484});
# CREATE (:Node {name: "getDepuiVersion", file: "wwpdb/apps/deposit/depui/depuiVersion.py", line: 4});
# CREATE (:Node {name: "report_em_issues", file: "wwpdb/apps/deposit/depui/upload.py", line: 3356});
# CREATE (:Node {name: "reset_ligands_and_status", file: "wwpdb/apps/deposit/depui/upload.py", line: 2593});
# CREATE (:Node {name: "remove_old_maps", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 10393});
# CREATE (:Node {name: "check_em_upload", file: "wwpdb/apps/deposit/depui/upload.py", line: 3142});
# CREATE (:Node {name: "set_internal_files", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 9584});
# CREATE (:Node {name: "getDBstatus", file: "wwpdb/apps/deposit/depui/FileConversion.py", line: 60});
# CREATE (:Node {name: "populate_em_map_upload", file: "wwpdb/apps/deposit/depui/upload.py", line: 2927});
# CREATE (:Node {name: "loadFromPickle", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 3547});
# CREATE (:Node {name: "run_workflows", file: "wwpdb/apps/deposit/depui/upload.py", line: 2825});
# CREATE (:Node {name: "noValidate", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 6788});
# CREATE (:Node {name: "get_previous_data_on_reset", file: "wwpdb/apps/deposit/depui/upload.py", line: 2849});
# CREATE (:Node {name: "get_em_map_upload", file: "wwpdb/apps/deposit/depui/upload.py", line: 2916});
# CREATE (:Node {name: "mergeData", file: "wwpdb/apps/deposit/depui/FileConversion.py", line: 2445});
# CREATE (:Node {name: "check_em", file: "wwpdb/apps/deposit/depui/upload.py", line: 2747});
# CREATE (:Node {name: "saveListToPickle", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 6672});
# CREATE (:Node {name: "save", file: "wwpdb/apps/deposit/depui/models.py", line: 202});
# CREATE (:Node {name: "check_related", file: "wwpdb/apps/deposit/depui/upload.py", line: 1338});
# CREATE (:Node {name: "populate_em_experiment", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 10519});
# CREATE (:Node {name: "getDBFiles", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 1208});
# CREATE (:Node {name: "ss_create_long_event", file: "wwpdb/apps/deposit/depui/upload.py", line: 1330});
# CREATE (:Node {name: "copy_existing_files_to_tempdep", file: "wwpdb/apps/deposit/depui/upload.py", line: 1543});
# CREATE (:Node {name: "prepare_onedep_folders", file: "wwpdb/apps/deposit/depui/upload.py", line: 1515});
# CREATE (:Node {name: "process_files", file: "wwpdb/apps/deposit/depui/upload.py", line: 1795});
# CREATE (:Node {name: "check_block_edit", file: "wwpdb/apps/deposit/depui/upload.py", line: 2556});
# CREATE (:Node {name: "copy_from_tempdep_to_deposit", file: "wwpdb/apps/deposit/depui/upload.py", line: 2610});
# CREATE (:Node {name: "populate_map", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 10556});
# CREATE (:Node {name: "add_related_info", file: "wwpdb/apps/deposit/depui/upload.py", line: 2097});
# CREATE (:Node {name: "get_experiment_types", file: "wwpdb/apps/deposit/depui/upload.py", line: 1197});
# CREATE (:Node {name: "addStatus", file: "wwpdb/apps/deposit/depui/status.py", line: 240});
# CREATE (:Node {name: "getStatusCode", file: "wwpdb/apps/wf_engine/engine/WFEapplications.py", line: 802});
# CREATE (:Node {name: "runSelectSQL", file: "wwpdb/utils/wf/dbapi/WfDbApi.py", line: 195});
# CREATE (:Node {name: "runSelectSQL", file: "wwpdb/utils/wf/dbapi/DbCommand.py", line: 213});
# CREATE (:Node {name: "createTimeStamp", file: "wwpdb/apps/deposit/depui/snapshot/Snapshot.py", line: 644});
# CREATE (:Node {name: "close", file: "wwpdb/apps/wf_engine/engine/dbAPI.py", line: 22});
# CREATE (:Node {name: "runInsertNQ", file: "wwpdb/apps/wf_engine/engine/dbAPI.py", line: 141});
# CREATE (:Node {name: "runInsertSQL", file: "wwpdb/utils/wf/dbapi/DbCommand.py", line: 190});
# CREATE (:Node {name: "runUpdateSQL", file: "wwpdb/utils/wf/dbapi/DbCommand.py", line: 193});
# CREATE (:Node {name: "runInsertSQL", file: "wwpdb/utils/wf/dbapi/WfDbApi.py", line: 151});
# CREATE (:Node {name: "runInsert", file: "wwpdb/apps/wf_engine/engine/dbAPI.py", line: 151});
# CREATE (:Node {name: "close", file: "wwpdb/utils/wf/dbapi/WfDbApi.py", line: 141});
# CREATE (:Node {name: "close", file: "wwpdb/utils/wf/dbapi/DbConnection.py", line: 115});
# CREATE (:Node {name: "createLongEvent", file: "wwpdb/apps/deposit/depui/snapshot/Snapshot.py", line: 604});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/snapshot/Experiments.py", line: 40});
# CREATE (:Node {name: "getCodes", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 516});
# CREATE (:Node {name: "getCodes", file: "wwpdb/apps/deposit/depui/snapshot/Experiments.py", line: 67});
# CREATE (:Node {name: "runSelect", file: "wwpdb/apps/wf_engine/engine/dbAPI.py", line: 33});
# CREATE (:Node {name: "runSelectNQ", file: "wwpdb/apps/wf_engine/engine/dbAPI.py", line: 26});
# CREATE (:Node {name: "getRequestedCodes", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 3498});
# CREATE (:Node {name: "getDataType", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 3510});
# CREATE (:Node {name: "getExperiments", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 526});
# CREATE (:Node {name: "getExperiments", file: "wwpdb/apps/deposit/depui/snapshot/Experiments.py", line: 45});
# CREATE (:Node {name: "getDirPath", file: "wwpdb/io/locator/PathInfo.py", line: 432});
# CREATE (:Node {name: "setSessionDataSetId", file: "wwpdb/io/locator/DataReference.py", line: 565});
# CREATE (:Node {name: "getDirPathReference", file: "wwpdb/io/locator/DataReference.py", line: 719});
# CREATE (:Node {name: "getDir", file: "wwpdb/apps/deposit/depui/common_functions.py", line: 135});
# CREATE (:Node {name: "getUploadsFile", file: "wwpdb/apps/deposit/depui/common_functions.py", line: 141});
# CREATE (:Node {name: "path", file: "wwpdb/apps/deposit/depui/models.py", line: 199});
# CREATE (:Node {name: "basename", file: "wwpdb/apps/deposit/depui/models.py", line: 195});
# CREATE (:Node {name: "getCategoriesToUpdate", file: "wwpdb/apps/deposit/depui/constants.py", line: 2197});
# CREATE (:Node {name: "getExperimentsWithSubtypes", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 3537});
# CREATE (:Node {name: "get_all_flags", file: "wwpdb/apps/deposit/depui/snapshot/EntryFlags.py", line: 28});
# CREATE (:Node {name: "check_upload_complete", file: "wwpdb/apps/deposit/depui/upload.py", line: 166});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/snapshot/EntryFlags.py", line: 23});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 24});
# CREATE (:Node {name: "run_process", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 216});
# CREATE (:Node {name: "get_warning_string", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 88});
# CREATE (:Node {name: "get_error_string", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 80});
# CREATE (:Node {name: "process_files", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 142});
# CREATE (:Node {name: "process_submitted_files", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 131});
# CREATE (:Node {name: "process_active_types", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 127});
# CREATE (:Node {name: "process_new_files", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 138});
# CREATE (:Node {name: "__repr__", file: "wwpdb/apps/deposit/depui/models.py", line: 205});
# CREATE (:Node {name: "get_submitted_warning", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 194});
# CREATE (:Node {name: "check_tarball", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 257});
# CREATE (:Node {name: "check_diffraction", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 423});
# CREATE (:Node {name: "check_nmr", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 276});
# CREATE (:Node {name: "check_ec", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 498});
# CREATE (:Node {name: "check_none_types", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 233});
# CREATE (:Node {name: "check_pdb", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 475});
# CREATE (:Node {name: "check_emdb", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 444});
# CREATE (:Node {name: "is_nmr", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 96});
# CREATE (:Node {name: "is_ec", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 103});
# CREATE (:Node {name: "is_diffraction", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 117});
# CREATE (:Node {name: "get_submitted_file_count", file: "wwpdb/apps/deposit/depui/check_upload_complete.py", line: 135});
# CREATE (:Node {name: "create_onedep_folder", file: "wwpdb/apps/deposit/depui/upload.py", line: 1498});
# CREATE (:Node {name: "clear_out_folder", file: "wwpdb/apps/deposit/depui/upload.py", line: 1026});
# CREATE (:Node {name: "load_pickle", file: "wwpdb/apps/deposit/depui/PickleUtil.py", line: 288});
# CREATE (:Node {name: "does_pickle_exist", file: "wwpdb/apps/deposit/depui/PickleUtil.py", line: 85});
# CREATE (:Node {name: "load_from_pickle", file: "wwpdb/apps/deposit/depui/PickleUtil.py", line: 248});
# CREATE (:Node {name: "clean_em_categories", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 9432});
# CREATE (:Node {name: "clean_em_software", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 9450});
# CREATE (:Node {name: "is_em_or_ec", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 10191});
# CREATE (:Node {name: "pull_from_em_map", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 10270});
# CREATE (:Node {name: "get_original_name_from_db", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 10354});
# CREATE (:Node {name: "update_em_map_file_names", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 10199});
# CREATE (:Node {name: "check_em_map_matches_DB", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 10226});
# CREATE (:Node {name: "getCategoryItems", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 7633});
# CREATE (:Node {name: "removeAllValuesFromInstance", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 3042});
# CREATE (:Node {name: "fetchItemValue", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8833});
# CREATE (:Node {name: "newItemValue", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8913});
# CREATE (:Node {name: "isNmrUnifiedDeposition", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 9908});
# CREATE (:Node {name: "isNmrLegacyDeposition", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 9885});
# CREATE (:Node {name: "get_original_map_name", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 10493});
# CREATE (:Node {name: "get_map_where", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 10469});
# CREATE (:Node {name: "__init__", file: "wwpdb/io/locator/PathInfo.py", line: 61});
# CREATE (:Node {name: "parseFileName", file: "wwpdb/io/locator/PathInfo.py", line: 78});
# CREATE (:Node {name: "__init__", file: "wwpdb/io/locator/DataReference.py", line: 145});
# CREATE (:Node {name: "__reset", file: "wwpdb/io/locator/DataReference.py", line: 157});
# CREATE (:Node {name: "__init__", file: "wwpdb/io/locator/DataReference.py", line: 79});
# CREATE (:Node {name: "get", file: "wwpdb/io/locator/DataReference.py", line: 170});
# CREATE (:Node {name: "set", file: "wwpdb/io/locator/DataReference.py", line: 165});
# CREATE (:Node {name: "__splitFileName", file: "wwpdb/io/locator/DataReference.py", line: 176});
# CREATE (:Node {name: "getFormatTypes", file: "wwpdb/io/locator/DataReference.py", line: 111});
# CREATE (:Node {name: "contentTypeExists", file: "wwpdb/io/locator/DataReference.py", line: 99});
# CREATE (:Node {name: "getExtensionFormats", file: "wwpdb/io/locator/DataReference.py", line: 123});
# CREATE (:Node {name: "save_pickle", file: "wwpdb/apps/deposit/depui/PickleUtil.py", line: 312});
# CREATE (:Node {name: "getEvents", file: "wwpdb/apps/deposit/depui/snapshot/Snapshot.py", line: 540});
# CREATE (:Node {name: "new_cat_instance", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8926});
# CREATE (:Node {name: "get_em_map_upload_index", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 10441});
# CREATE (:Node {name: "get_map_index", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 10446});
# CREATE (:Node {name: "validateInstance", file: "wwpdb/apps/deposit/depui/validation.py", line: 22});
# CREATE (:Node {name: "getItemMetaData", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 7650});
# CREATE (:Node {name: "runUIhacks", file: "wwpdb/apps/deposit/depui/upload.py", line: 369});
# CREATE (:Node {name: "clearUIlock", file: "wwpdb/apps/deposit/depui/hiddenData/setHidden.py", line: 237});
# CREATE (:Node {name: "get_partNo_EM_map", file: "wwpdb/apps/deposit/depui/upload.py", line: 3038});
# CREATE (:Node {name: "getFileTypeMatch", file: "wwpdb/apps/deposit/depui/FileConversion.py", line: 584});
# CREATE (:Node {name: "createFileEvent", file: "wwpdb/apps/deposit/depui/snapshot/Snapshot.py", line: 598});
# CREATE (:Node {name: "writeMileStone", file: "wwpdb/apps/deposit/depui/common_functions.py", line: 160});
# CREATE (:Node {name: "update_em_parameters", file: "wwpdb/apps/deposit/depui/upload.py", line: 1617});
# CREATE (:Node {name: "calculate_centre_of_mass_for_xray", file: "wwpdb/apps/deposit/depui/upload.py", line: 334});
# CREATE (:Node {name: "do_file_action", file: "wwpdb/apps/deposit/depui/upload.py", line: 1700});
# CREATE (:Node {name: "check_em_conversion", file: "wwpdb/apps/deposit/depui/upload.py", line: 1739});
# CREATE (:Node {name: "__map_sorter", file: "wwpdb/apps/deposit/depui/upload.py", line: 1809});
# CREATE (:Node {name: "do_file_merge", file: "wwpdb/apps/deposit/depui/upload.py", line: 1667});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/hiddenData/setHidden.py", line: 34});
# CREATE (:Node {name: "runFormatModelCheckWf", file: "wwpdb/apps/deposit/depui/upload.py", line: 272});
# CREATE (:Node {name: "decompressAndCopyFile", file: "wwpdb/apps/deposit/depui/upload.py", line: 775});
# CREATE (:Node {name: "getSystemFileType", file: "wwpdb/apps/deposit/depui/upload.py", line: 455});
# CREATE (:Node {name: "setPartitionNumber", file: "wwpdb/io/locator/DataReference.py", line: 603});
# CREATE (:Node {name: "check_file_format", file: "wwpdb/apps/deposit/depui/upload.py", line: 642});
# CREATE (:Node {name: "shutil_copy", file: "wwpdb/apps/deposit/depui/common_functions.py", line: 147});
# CREATE (:Node {name: "checkNonAscii", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 943});
# CREATE (:Node {name: "setExternalFilePath", file: "wwpdb/io/locator/DataReference.py", line: 369});
# CREATE (:Node {name: "getFileObject", file: "wwpdb/apps/deposit/depui/common_functions.py", line: 96});
# CREATE (:Node {name: "badVersionNumber", file: "wwpdb/apps/deposit/depui/common_functions.py", line: 80});
# CREATE (:Node {name: "write_EM_parameters", file: "wwpdb/apps/deposit/depui/upload.py", line: 4153});
# CREATE (:Node {name: "doComplexConvertWf", file: "wwpdb/apps/deposit/depui/FileConversion.py", line: 112});
# CREATE (:Node {name: "complexLogFile", file: "wwpdb/apps/deposit/depui/FileConversion.py", line: 1263});
# CREATE (:Node {name: "wfStart", file: "wwpdb/apps/deposit/depui/FileConversion.py", line: 100});
# CREATE (:Node {name: "wfFinished", file: "wwpdb/apps/deposit/depui/FileConversion.py", line: 74});
# CREATE (:Node {name: "snapshotCreateActionEvent", file: "wwpdb/apps/deposit/depui/FileConversion.py", line: 108});
# CREATE (:Node {name: "wfStatus", file: "wwpdb/apps/deposit/depui/FileConversion.py", line: 104});
# CREATE (:Node {name: "runOutOfBandWorkflow", file: "wwpdb/apps/wf_engine/engine/WFEapplications.py", line: 61});
# CREATE (:Node {name: "runUpdateSQL", file: "wwpdb/utils/wf/dbapi/WfDbApi.py", line: 172});
# CREATE (:Node {name: "getTimeNow", file: "wwpdb/utils/wf/dbapi/WFEtime.py", line: 14});
# CREATE (:Node {name: "getWfStatus", file: "wwpdb/apps/wf_engine/engine/WFEapplications.py", line: 132});
# CREATE (:Node {name: "createActionEvent", file: "wwpdb/apps/deposit/depui/snapshot/Snapshot.py", line: 610});
# CREATE (:Node {name: "getFile", file: "wwpdb/apps/deposit/depui/common_functions.py", line: 117});
# CREATE (:Node {name: "convertFileEvent", file: "wwpdb/apps/deposit/depui/snapshot/Snapshot.py", line: 592});
# CREATE (:Node {name: "doEMImageProcessing", file: "wwpdb/apps/deposit/depui/FileConversion.py", line: 2329});
# CREATE (:Node {name: "getFileContentsEM", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 791});
# CREATE (:Node {name: "report_image_errors", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 619});
# CREATE (:Node {name: "dumpReport", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 716});
# CREATE (:Node {name: "getProcessPartition", file: "wwpdb/apps/deposit/depui/snapshot/Snapshot.py", line: 516});
# CREATE (:Node {name: "getReportData", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 733});
# CREATE (:Node {name: "report_fsc_errors", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 164});
# CREATE (:Node {name: "collate_errors", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 763});
# CREATE (:Node {name: "get_original_names", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 127});
# CREATE (:Node {name: "report_map_errors", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 233});
# CREATE (:Node {name: "get_file_for_content_type_format", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 97});
# CREATE (:Node {name: "getLatestMapReportFile", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 700});
# CREATE (:Node {name: "getPartition", file: "wwpdb/apps/deposit/depui/snapshot/Snapshot.py", line: 482});
# CREATE (:Node {name: "map_parameters", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 52});
# CREATE (:Node {name: "check_half_map_consistency", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 458});
# CREATE (:Node {name: "lookup_report_name", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 373});
# CREATE (:Node {name: "check_contour", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 658});
# CREATE (:Node {name: "getPartitionNumberFromFile", file: "wwpdb/apps/deposit/depui/common_functions.py", line: 70});
# CREATE (:Node {name: "fetch_converted_file", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 576});
# CREATE (:Node {name: "check_consistency", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 393});
# CREATE (:Node {name: "get_summary_for_summary_page", file: "wwpdb/apps/deposit/depui/dataObject/getContentEM.py", line: 531});
# CREATE (:Node {name: "checkIfAscii", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 968});
# CREATE (:Node {name: "getUploadValidate", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 6179});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/dataObject/getContent.py", line: 16});
# CREATE (:Node {name: "returnFileContents", file: "wwpdb/apps/deposit/depui/dataObject/getContent.py", line: 20});
# CREATE (:Node {name: "get_coordinate_errors", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 258});
# CREATE (:Node {name: "get_warnings", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 107});
# CREATE (:Node {name: "populate_coordinate_warnings", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 84});
# CREATE (:Node {name: "populate_warnings_and_errors", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 93});
# CREATE (:Node {name: "get_upload_complex_report", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 6320});
# CREATE (:Node {name: "atoms_with_zero_occupancy", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 156});
# CREATE (:Node {name: "getUploadValidateMergeReport", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 6310});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 9});
# CREATE (:Node {name: "get_sf_errors", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 266});
# CREATE (:Node {name: "get_errors", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 103});
# CREATE (:Node {name: "getUploadValidateEM", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 6162});
# CREATE (:Node {name: "get_structure_factor_report_json_contents", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 48});
# CREATE (:Node {name: "populate_sf_report", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 71});
# CREATE (:Node {name: "get_coordinate_warnings", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 119});
# CREATE (:Node {name: "get_aniso_no_tls", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 111});
# CREATE (:Node {name: "populate_full_coord_report", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 64});
# CREATE (:Node {name: "get_method_specific_errors", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 193});
# CREATE (:Node {name: "get_coords_issues_json_contents", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 32});
# CREATE (:Node {name: "populate_coordinate_cell_issues", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 77});
# CREATE (:Node {name: "populate_coordinate_issues", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 81});
# CREATE (:Node {name: "populate_coordinate_errors", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 74});
# CREATE (:Node {name: "populate_coordinate_information", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 87});
# CREATE (:Node {name: "populate_coord_space_group", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 90});
# CREATE (:Node {name: "get_sequence_issues", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 124});
# CREATE (:Node {name: "bracket_at_end_of_polymer", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 131});
# CREATE (:Node {name: "get_pdb_coordinate_errors", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 159});
# CREATE (:Node {name: "get_occupancy_issues", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 127});
# CREATE (:Node {name: "ligands_with_zero_occupancy", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 149});
# CREATE (:Node {name: "is_diffraction", file: "wwpdb/apps/deposit/depui/checks/warnings_and_errors.py", line: 187});
# CREATE (:Node {name: "itemVisibility", file: "wwpdb/apps/deposit/depui/hiddenData/setHidden.py", line: 121});
# CREATE (:Node {name: "createUI", file: "wwpdb/apps/deposit/depui/precalc/createIDs.py", line: 416});
# CREATE (:Node {name: "createLigandTags", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 994});
# CREATE (:Node {name: "readCif", file: "wwpdb/apps/deposit/depui/precalc/createIDs.py", line: 155});
# CREATE (:Node {name: "writeCif", file: "wwpdb/apps/deposit/depui/precalc/createIDs.py", line: 411});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/precalc/createIDs.py", line: 40});
# CREATE (:Node {name: "scan_cif", file: "wwpdb/apps/deposit/depui/precalc/createIDs.py", line: 73});
# CREATE (:Node {name: "updateCIF", file: "wwpdb/apps/deposit/depui/precalc/createIDs.py", line: 165});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxIoUtil.py", line: 30});
# CREATE (:Node {name: "loadFile", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxIoUtil.py", line: 35});
# CREATE (:Node {name: "getPickleBaseDictionary", file: "wwpdb/apps/deposit/depui/mmcif_dictionary/dictionary_access.py", line: 35});
# CREATE (:Node {name: "getDictionaryPath", file: "wwpdb/apps/deposit/depui/mmcif_dictionary/dictionary_access.py", line: 18});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/mmcif_dictionary/PdbxDict.py", line: 31});
# CREATE (:Node {name: "getmmCIFDictionaryFile", file: "wwpdb/apps/deposit/depui/mmcif_dictionary/dictionary_access.py", line: 7});
# CREATE (:Node {name: "__setup", file: "wwpdb/apps/deposit/depui/mmcif_dictionary/PdbxDict.py", line: 44});
# CREATE (:Node {name: "readSerializedDictionary", file: "wwpdb/apps/deposit/depui/mmcif_dictionary/PdbxDictionaryLoader.py", line: 61});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/mmcif_dictionary/PdbxDictionaryLoader.py", line: 35});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py", line: 41});
# CREATE (:Node {name: "getSetInstanceText", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py", line: 162});
# CREATE (:Node {name: "getBlock", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py", line: 98});
# CREATE (:Node {name: "getSetInstanceCount", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py", line: 170});
# CREATE (:Node {name: "setFilePath", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py", line: 73});
# CREATE (:Node {name: "getCategoryItemSetNames", file: "wwpdb/apps/deposit/depui/mmcif_dictionary/PdbxDict.py", line: 78});
# CREATE (:Node {name: "setFilterCifNull", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py", line: 63});
# CREATE (:Node {name: "getInstance", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py", line: 198});
# CREATE (:Node {name: "__getDataBlock", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py", line: 401});
# CREATE (:Node {name: "__getDataBlockList", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py", line: 389});
# CREATE (:Node {name: "__setDataBlock", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py", line: 425});
# CREATE (:Node {name: "__setCategoryByName", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py", line: 353});
# CREATE (:Node {name: "getCategoryItemSet", file: "wwpdb/apps/deposit/depui/mmcif_dictionary/PdbxDict.py", line: 98});
# CREATE (:Node {name: "__getInstanceCategory", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py", line: 375});
# CREATE (:Node {name: "__getInstanceItemIndex", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py", line: 440});
# CREATE (:Node {name: "__bundleInstance", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py", line: 282});
# CREATE (:Node {name: "__initBundle", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py", line: 273});
# CREATE (:Node {name: "__getRowValue", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py", line: 337});
# CREATE (:Node {name: "add_extra_information", file: "wwpdb/apps/deposit/depui/precalc/createIDs.py", line: 147});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 87});
# CREATE (:Node {name: "writeCif", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 934});
# CREATE (:Node {name: "add_uploaded_files", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 812});
# CREATE (:Node {name: "write_out_issues_json", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 744});
# CREATE (:Node {name: "process_coordinate_file", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 178});
# CREATE (:Node {name: "prepare_issues_for_json", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 724});
# CREATE (:Node {name: "scanAtomSite", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 546});
# CREATE (:Node {name: "addData", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 835});
# CREATE (:Node {name: "check_extra_categories", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 331});
# CREATE (:Node {name: "stripContent", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 790});
# CREATE (:Node {name: "get_polymer_sequences", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 309});
# CREATE (:Node {name: "get_category_data", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 536});
# CREATE (:Node {name: "correct_pdbx_refine_id", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 337});
# CREATE (:Node {name: "check_tls", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 472});
# CREATE (:Node {name: "check_for_aniso", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 489});
# CREATE (:Node {name: "checkSoftware", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 396});
# CREATE (:Node {name: "test_residual_b", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 478});
# CREATE (:Node {name: "get_cell_symmetry", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 521});
# CREATE (:Node {name: "checkRefine", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 374});
# CREATE (:Node {name: "check_depui_status_flags", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 495});
# CREATE (:Node {name: "checkRefineAndSoftware", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 406});
# CREATE (:Node {name: "test_occupancy", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 667});
# CREATE (:Node {name: "getNewDefinition", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 270});
# CREATE (:Node {name: "test_bfactor", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 698});
# CREATE (:Node {name: "ExistingInstance", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 213});
# CREATE (:Node {name: "test_invalid_asym_id", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 650});
# CREATE (:Node {name: "test_has_tls_group_id", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 645});
# CREATE (:Node {name: "getFormula", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 241});
# CREATE (:Node {name: "test_len_asym_id", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 655});
# CREATE (:Node {name: "getFormulaString", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 769});
# CREATE (:Node {name: "isWater", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 231});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/precalc/LigandDefinition.py", line: 35});
# CREATE (:Node {name: "getNewInstance", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 255});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/precalc/LigandInstance.py", line: 23});
# CREATE (:Node {name: "check_pdbx_refine_tls_group", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 435});
# CREATE (:Node {name: "check_tls_and_aniso", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 441});
# CREATE (:Node {name: "check_pdbx_refine_tls", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 410});
# CREATE (:Node {name: "check_all_tls_categories", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 450});
# CREATE (:Node {name: "is_unknown_het_in_sequence", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 74});
# CREATE (:Node {name: "remove_category", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 779});
# CREATE (:Node {name: "add_extra_information", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 804});
# CREATE (:Node {name: "analyse_occupancy_of_ligands", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 714});
# CREATE (:Node {name: "get_next_pdbx_for_content_type", file: "wwpdb/apps/deposit/depui/precalc/createLigandTags.py", line: 206});
# CREATE (:Node {name: "update_recursive", file: "wwpdb/apps/deposit/depui/upload.py", line: 3363});
# CREATE (:Node {name: "postModifyAssembly", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 3886});
# CREATE (:Node {name: "postModifyData", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2220});
# CREATE (:Node {name: "buildIntegrated", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 7040});
# CREATE (:Node {name: "loadDictionary", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 639});
# CREATE (:Node {name: "postModifyExptl", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 4436});
# CREATE (:Node {name: "postModifyMeta", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 3764});
# CREATE (:Node {name: "load_multiple_data_blocks", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxIoUtil.py", line: 103});
# CREATE (:Node {name: "getBlockList", file: "wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstReader.py", line: 113});
# CREATE (:Node {name: "getPickleDictionary", file: "wwpdb/apps/deposit/depui/mmcif_dictionary/dictionary_access.py", line: 27});
# CREATE (:Node {name: "get", file: "wwpdb/apps/deposit/depui/mmcif_dictionary/PdbxDictionaryLoader.py", line: 40});
# CREATE (:Node {name: "crossCategoryItemValidation", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8478});
# CREATE (:Node {name: "crossTermRegexCheck", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8527});
# CREATE (:Node {name: "enumerateListHacks", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 7502});
# CREATE (:Node {name: "conditionalCrossTermValidCatOnly", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8223});
# CREATE (:Node {name: "crossTermOptionEnumerationItems", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8551});
# CREATE (:Node {name: "crossTermValidConditionalPresenceItems", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8361});
# CREATE (:Node {name: "crossTermValidOneAtLeast", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8605});
# CREATE (:Node {name: "getConstReplace", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 6963});
# CREATE (:Node {name: "crossTermValidSimple", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8302});
# CREATE (:Node {name: "crossTermValidMakeMandatory", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8442});
# CREATE (:Node {name: "getItemValue", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8968});
# CREATE (:Node {name: "crossTermValidMakeMandatorySubtype", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8403});
# CREATE (:Node {name: "validate_hacks", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8070});
# CREATE (:Node {name: "crossTermValid", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8674});
# CREATE (:Node {name: "return_allowed_author_list", file: "wwpdb/apps/deposit/depui/allowed_authors.py", line: 140});
# CREATE (:Node {name: "fieldValidate", file: "wwpdb/apps/deposit/depui/validation.py", line: 255});
# CREATE (:Node {name: "backward_support_for_boundary", file: "wwpdb/apps/deposit/depui/validation.py", line: 229});
# CREATE (:Node {name: "get_pickle", file: "wwpdb/apps/deposit/depui/allowed_authors.py", line: 35});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/allowed_authors.py", line: 29});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/allowed_authors.py", line: 97});
# CREATE (:Node {name: "read_dictionary", file: "wwpdb/apps/deposit/depui/allowed_authors.py", line: 38});
# CREATE (:Node {name: "return_sg_groups", file: "wwpdb/apps/deposit/depui/allowed_authors.py", line: 103});
# CREATE (:Node {name: "get_sg_groups_initials", file: "wwpdb/apps/deposit/depui/allowed_authors.py", line: 123});
# CREATE (:Node {name: "return_enumeration", file: "wwpdb/apps/deposit/depui/allowed_authors.py", line: 60});
# CREATE (:Node {name: "get_sg_groups_partial_name", file: "wwpdb/apps/deposit/depui/allowed_authors.py", line: 131});
# CREATE (:Node {name: "get_full_sg_groups", file: "wwpdb/apps/deposit/depui/allowed_authors.py", line: 115});
# CREATE (:Node {name: "return_enumeration_with_detail", file: "wwpdb/apps/deposit/depui/allowed_authors.py", line: 75});
# CREATE (:Node {name: "crossTermValidConditionalPresence", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8377});
# CREATE (:Node {name: "crossTermOptionEnumeration", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8566});
# CREATE (:Node {name: "get_instances", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8616});
# CREATE (:Node {name: "getCrossTermValidOneAtLeastItemsAndError", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8598});
# CREATE (:Node {name: "testLimits", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8637});
# CREATE (:Node {name: "get_category_item_values", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 7711});
# CREATE (:Node {name: "validateData", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8809});
# CREATE (:Node {name: "fetchItemLength", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 8709});
# CREATE (:Node {name: "putNmolecule", file: "wwpdb/apps/deposit/depui/snapshot/OtherData.py", line: 171});
# CREATE (:Node {name: "getDBstatus", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 7871});
# CREATE (:Node {name: "advancedCheckMenuItemsState", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2918});
# CREATE (:Node {name: "setBrainCif", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2332});
# CREATE (:Node {name: "checkMenuItemsState", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2466});
# CREATE (:Node {name: "runInsertUpdate", file: "wwpdb/apps/wf_engine/engine/dbAPI.py", line: 199});
# CREATE (:Node {name: "runUpdate", file: "wwpdb/apps/wf_engine/engine/dbAPI.py", line: 178});
# CREATE (:Node {name: "runInsertUpdateNQ", file: "wwpdb/apps/wf_engine/engine/dbAPI.py", line: 128});
# CREATE (:Node {name: "isSG", file: "wwpdb/apps/deposit/depui/snapshot/OtherData.py", line: 184});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/snapshot/UserData.py", line: 18});
# CREATE (:Node {name: "getRelatedCode", file: "wwpdb/apps/deposit/depui/snapshot/Related.py", line: 54});
# CREATE (:Node {name: "getRelatedDB", file: "wwpdb/apps/deposit/depui/snapshot/Related.py", line: 34});
# CREATE (:Node {name: "getUserData", file: "wwpdb/apps/deposit/depui/snapshot/UserData.py", line: 24});
# CREATE (:Node {name: "validateEmailsInContacts", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 6735});
# CREATE (:Node {name: "get_valid_orcid", file: "wwpdb/apps/deposit/depui/snapshot/EntryFlags.py", line: 186});
# CREATE (:Node {name: "__init__", file: "wwpdb/apps/deposit/depui/snapshot/Related.py", line: 29});
# CREATE (:Node {name: "get_flag", file: "wwpdb/apps/deposit/depui/snapshot/EntryFlags.py", line: 55});
# CREATE (:Node {name: "checkEmailsInContacts", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 6728});
# CREATE (:Node {name: "checkEmailsInContactsCore", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 6751});
# CREATE (:Node {name: "returnMenuItemsState", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2388});
# CREATE (:Node {name: "_advancedCheckMenuItemsStateGenerateKeyValue", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2652});
# CREATE (:Node {name: "_advancedCheckMenuItemsStateRetrieveItems", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2683});
# CREATE (:Node {name: "_advancedCheckMenuItemsStateGetCheckInstNum", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2739});
# CREATE (:Node {name: "_advancedCheckMenuItemsStateFailValue", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2776});
# CREATE (:Node {name: "_advancedCheckMenuItemsStateEvaluateLogicState", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2794});
# CREATE (:Node {name: "_advancedCheckMenuItemsStateSetFailstate", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2670});
# CREATE (:Node {name: "advancedCheckMenuItemsStateFlagsList", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2843});
# CREATE (:Node {name: "_advancedCheckMenuItemsStateEvaluateValues", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2751});
# CREATE (:Node {name: "_advancedCheckMenuItemsStateGetValues", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2710});
# CREATE (:Node {name: "_advancedCheckMenuItemsStateRetrieveSetFieldAndKey", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2628});
# CREATE (:Node {name: "_advancedCheckMenuItemsStateGetInstNum", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2587});
# CREATE (:Node {name: "advancedReturnMenuItemState", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 2550});
# CREATE (:Node {name: "update_assembly_form", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 4220});
# CREATE (:Node {name: "save_matrices_from_cif_to_depositor_info", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 4360});
# CREATE (:Node {name: "save_assembly_to_json", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 4007});
# CREATE (:Node {name: "validate_assembly_cif_items", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 4123});
# CREATE (:Node {name: "get_chain_id_list_for_assembly", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 4108});
# CREATE (:Node {name: "get_chain_id_for_assembly", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 4079});
# CREATE (:Node {name: "trim_categories", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 4427});
# CREATE (:Node {name: "get_matrices_from_string", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 4398});
# CREATE (:Node {name: "save_assembly_to_cif", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 773});
# CREATE (:Node {name: "getDepositPath", file: "wwpdb/io/locator/PathInfo.py", line: 154});
# CREATE (:Node {name: "get_assembly_model_cif_file", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 767});
# CREATE (:Node {name: "getAssemblyModelFilePath", file: "wwpdb/io/locator/PathInfo.py", line: 389});
# CREATE (:Node {name: "__getPathWorker", file: "wwpdb/io/locator/PathInfo.py", line: 530});
# CREATE (:Node {name: "getVersionIdSearchTarget", file: "wwpdb/io/locator/DataReference.py", line: 993});
# CREATE (:Node {name: "isReferenceValid", file: "wwpdb/io/locator/DataReference.py", line: 697});
# CREATE (:Node {name: "getContentTypeSearchTarget", file: "wwpdb/io/locator/DataReference.py", line: 1215});
# CREATE (:Node {name: "__getStandardPath", file: "wwpdb/io/locator/PathInfo.py", line: 512});
# CREATE (:Node {name: "buildValues", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 7556});
# CREATE (:Node {name: "saveToCif", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 708});
# CREATE (:Node {name: "loadFullCif", file: "wwpdb/apps/deposit/depui/apilayer.py", line: 649});
# ...
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=get_validate_polymer_linkage\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1705"}), (b:Node {name: "name=fetchItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8833"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=get_peptide_omega_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1921"}), (b:Node {name: "name=fetchItemLength\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8709"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=get_peptide_omega_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1921"}), (b:Node {name: "name=fetchItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8833"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=get_bond_angle_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1765"}), (b:Node {name: "name=fetchItemLength\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8709"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=get_bond_angle_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1765"}), (b:Node {name: "name=fetchItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8833"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=get_other_plane_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1850"}), (b:Node {name: "name=fetchItemLength\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8709"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=get_other_plane_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1850"}), (b:Node {name: "name=fetchItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8833"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=getSymmClashes\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=2045"}), (b:Node {name: "name=get_clashes\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1980"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=get_bond_length_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1812"}), (b:Node {name: "name=fetchItemLength\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8709"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=get_bond_length_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1812"}), (b:Node {name: "name=fetchItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8833"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=get_solvent_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1953"}), (b:Node {name: "name=fetchItemLength\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8709"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=get_solvent_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1953"}), (b:Node {name: "name=fetchItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8833"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=get_main_chain_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1871"}), (b:Node {name: "name=fetchItemLength\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8709"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=get_main_chain_outliers\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1871"}), (b:Node {name: "name=fetchItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8833"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=safeRollStates\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=350"}), (b:Node {name: "name=__init__\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=13"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=safeRollStates\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=350"}), (b:Node {name: "name=runSelectNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=26"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=createOldModelStatus\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=272"}), (b:Node {name: "name=__init__\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=13"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=createOldModelStatus\nfile=wwpdb/apps/deposit/depui/snapshot/Snapshot.py\nline=272"}), (b:Node {name: "name=runSelectNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=26"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=getValidationStatus\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1479"}), (b:Node {name: "name=runSelectSQL\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=195"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=getValidationStatus\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1479"}), (b:Node {name: "name=noValidate\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6788"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=writeFileNoFix\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxIoUtil.py\nline=113"}), (b:Node {name: "name=__init__\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=43"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=writeFileNoFix\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxIoUtil.py\nline=113"}), (b:Node {name: "name=write\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=552"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=writeFileNoFix\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxIoUtil.py\nline=113"}), (b:Node {name: "name=updateDatasetIDContext\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=135"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=writeFileNoFix\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxIoUtil.py\nline=113"}), (b:Node {name: "name=setBlock\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=58"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=writeFileNoFix\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxIoUtil.py\nline=113"}), (b:Node {name: "name=unicodeHandler\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=79"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=writeFileNoFix\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxIoUtil.py\nline=113"}), (b:Node {name: "name=updateEntryContext\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=131"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=writeFileNoFix\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxIoUtil.py\nline=113"}), (b:Node {name: "name=appendContainer\nfile=wwpdb/apps/deposit/depui/mmcif_v2/PdbxCategoryItemSetInstWriter.py\nline=543"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=remove_excess_categories\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2380"}), (b:Node {name: "name=get_invalid_tags\nfile=wwpdb/apps/deposit/depui/testfunc.py\nline=41"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=remove_excess_categories\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2380"}), (b:Node {name: "name=fetchItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8833"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=remove_excess_categories\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2380"}), (b:Node {name: "name=newItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8913"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=remove_excess_categories\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2380"}), (b:Node {name: "name=get_provided_emdb\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7857"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=remove_excess_categories\nfile=wwpdb/apps/deposit/depui/upload.py\nline=2380"}), (b:Node {name: "name=saveProgress\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3583"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=initilliseDepositDict\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=473"}), (b:Node {name: "name=runUpdateSQL\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=172"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=initilliseDepositDict\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=473"}), (b:Node {name: "name=exist\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=593"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=getDBdataValues\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7893"}), (b:Node {name: "name=ascii_string\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7946"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=getDBdataValues\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7893"}), (b:Node {name: "name=getDataType\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3510"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=getDBdataValues\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7893"}), (b:Node {name: "name=__init__\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=68"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=getDBdataValues\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7893"}), (b:Node {name: "name=valueItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7960"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=getDBdataValues\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7893"}), (b:Node {name: "name=runSelectSQL\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=195"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=addDateIfDep\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7888"}), (b:Node {name: "name=getStatusCode\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=802"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=setProgress\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3737"}), (b:Node {name: "name=VALID_PROGRESS\nfile=wwpdb/apps/deposit/depui/constants.py\nline=3356"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=setProgress\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3737"}), (b:Node {name: "name=saveProgress\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=3583"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=get_provided_emdb\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7857"}), (b:Node {name: "name=__init__\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=42"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=get_provided_emdb\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=7857"}), (b:Node {name: "name=getItem\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=48"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=getItem\nfile=wwpdb/apps/deposit/depui/snapshot/OtherData.py\nline=48"}), (b:Node {name: "name=runSelectNQ\nfile=wwpdb/apps/wf_engine/engine/dbAPI.py\nline=26"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=deleteLigandState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1470"}), (b:Node {name: "name=__init__\nfile=wwpdb/apps/deposit/depui/dataObject/LiteState.py\nline=44"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=deleteLigandState\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=1470"}), (b:Node {name: "name=deleteStateFile\nfile=wwpdb/apps/deposit/depui/dataObject/LiteState.py\nline=115"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=deleteStateFile\nfile=wwpdb/apps/deposit/depui/dataObject/LiteState.py\nline=115"}), (b:Node {name: "name=getDir\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=135"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=deleteStateFile\nfile=wwpdb/apps/deposit/depui/dataObject/LiteState.py\nline=115"}), (b:Node {name: "name=locate\nfile=wwpdb/apps/deposit/depui/dataObject/LiteState.py\nline=286"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=update_map_file\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10459"}), (b:Node {name: "name=newItemValue\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=8913"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=update_map_file\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10459"}), (b:Node {name: "name=get_map_index\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=10446"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=get_latest_deposit_file\nfile=wwpdb/apps/deposit/depui/upload.py\nline=3732"}), (b:Node {name: "name=getFile\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=117"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=getUploadValidateEM_report\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6168"}), (b:Node {name: "name=getUploadValidateEM\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6162"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=runWorkflowOnUpload\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=680"}), (b:Node {name: "name=runUpdateSQL\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=172"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=runWorkflowOnUpload\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=680"}), (b:Node {name: "name=getTimeNow\nfile=wwpdb/utils/wf/dbapi/WFEtime.py\nline=14"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=runWorkflowOnUpload\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=680"}), (b:Node {name: "name=getValidationStatus\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=106"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=getValidationStatus\nfile=wwpdb/apps/wf_engine/engine/WFEapplications.py\nline=106"}), (b:Node {name: "name=runSelectSQL\nfile=wwpdb/utils/wf/dbapi/WfDbApi.py\nline=195"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=get_latest_deposit_file\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9752"}), (b:Node {name: "name=getFile\nfile=wwpdb/apps/deposit/depui/common_functions.py\nline=117"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
#
#
#             MATCH (a:Node {name: "name=remove_category_rows\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=9551"}), (b:Node {name: "name=saveToPickle\nfile=wwpdb/apps/deposit/depui/apilayer.py\nline=6699"})
#             CREATE (a)-[:DEPENDS_ON]->(b);
